# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings, os, joblib
from datetime import datetime, timedelta

# ML Models
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)
sns.set_theme(style='darkgrid', palette='muted')
plt.rcParams['figure.dpi'] = 120

REGIONS = ['DELHI', 'BRPL', 'BYPL', 'NDPL', 'NDMC', 'MES']
RANDOM_STATE = 42
print('✅ Imports done')
# Out:
# ✅ Imports done

# %%
DELHI_HOLIDAYS = [
    # 2022
    '2022-01-26','2022-03-01','2022-03-18','2022-04-10','2022-04-14',
    '2022-04-15','2022-05-03','2022-05-16','2022-07-10','2022-08-09',
    '2022-08-15','2022-08-19','2022-10-02','2022-10-05','2022-10-09',
    '2022-10-24','2022-10-25','2022-10-26','2022-11-08','2022-12-25',
    # 2023
    '2023-01-26','2023-02-18','2023-03-08','2023-03-30','2023-04-07',
    '2023-04-14','2023-04-21','2023-04-22','2023-05-05','2023-06-29',
    '2023-07-29','2023-08-15','2023-09-06','2023-09-07','2023-09-19',
    '2023-10-02','2023-10-24','2023-11-13','2023-11-14','2023-11-15',
    '2023-11-27','2023-12-25',
    # 2024
    '2024-01-22','2024-01-26','2024-03-08','2024-03-25','2024-03-29',
    '2024-04-09','2024-04-11','2024-04-14','2024-04-17','2024-05-23',
    '2024-06-17','2024-07-17','2024-08-15','2024-08-26','2024-09-16',
    '2024-10-02','2024-10-12','2024-10-13','2024-11-01','2024-11-02',
    '2024-11-03','2024-11-15','2024-12-25',
    # 2025
    '2025-01-26','2025-02-26','2025-03-14','2025-03-31','2025-04-06',
    '2025-04-10','2025-04-14','2025-05-12','2025-06-07','2025-07-06',
    '2025-08-15','2025-08-16','2025-09-05','2025-10-02','2025-10-20',
    '2025-10-21','2025-11-05','2025-12-25',
    # 2026
    '2026-01-26','2026-02-15','2026-03-20','2026-03-22','2026-03-27',
    '2026-03-29','2026-04-14'
]
HOLIDAY_SET = set(DELHI_HOLIDAYS)
print(f'✅ Loaded {len(HOLIDAY_SET)} unique holiday dates')

# Holiday impact summary
by_year = {}
for d in HOLIDAY_SET:
    yr = d[:4]
    by_year[yr] = by_year.get(yr, 0) + 1
for yr in sorted(by_year):
    print(f'  {yr}: {by_year[yr]} holidays')
# Out:
# ✅ Loaded 90 unique holiday dates
#   2022: 20 holidays
#   2023: 22 holidays
#   2024: 23 holidays
#   2025: 18 holidays
#   2026: 7 holidays

# %%
# ── IMPORTANT: Update paths if needed ──
SLDC_PATH    = 'delhi_sldc_5min_2022_2026.csv'   # electricity demand
WEATHER_PATH = 'Delhi_Weather_5M.csv'             # weather (5-min interpolated)

sldc = pd.read_csv(SLDC_PATH)
wx   = pd.read_csv(WEATHER_PATH)

# Parse datetime
sldc['datetime'] = pd.to_datetime(sldc['Date'] + ' ' + sldc['TimeSlot'], dayfirst=True)
wx['datetime']   = pd.to_datetime(wx['Date']   + ' ' + wx['TimeSlot'],   dayfirst=True)

sldc.sort_values('datetime', inplace=True)
wx.sort_values('datetime',   inplace=True)
sldc.reset_index(drop=True, inplace=True)
wx.reset_index(drop=True,   inplace=True)

print(f'SLDC  : {sldc.shape} | {sldc["datetime"].min()} → {sldc["datetime"].max()}')
print(f'Weather: {wx.shape}  | {wx["datetime"].min()} → {wx["datetime"].max()}')
print('\nSLDC columns:', list(sldc.columns))
print('Weather columns:', list(wx.columns))
# Out:
# SLDC  : (430782, 9) | 2022-01-01 00:00:00 → 2026-04-01 23:55:00
# Weather: (446965, 12)  | 2022-01-01 00:00:00 → 2026-04-01 23:00:00
#
# SLDC columns: ['Date', 'TimeSlot', 'DELHI', 'BRPL', 'BYPL', 'NDPL', 'NDMC', 'MES', 'datetime']
# Weather columns: ['Date', 'TimeSlot', 'Temperature (°C)', 'Relative Humidity (%)', 'Apparent Temperature (°C)', 'Precipitation (mm)', 'Wind Speed (m/s)', 'Cloud Cover Total (%)', 'Cloud Cover Low (%)', 'Cloud Cover Mid (%)', 'Cloud Cover High (%)', 'datetime']

# %%
print('=== SLDC Demand Stats (MW) ===')
print(sldc[REGIONS].describe().round(2))

print('\n=== Missing Values ===')
print(sldc[REGIONS].isnull().sum())
print(wx[['Temperature (°C)','Relative Humidity (%)','Apparent Temperature (°C)',
          'Precipitation (mm)','Wind Speed (m/s)','Cloud Cover Total (%)']].isnull().sum())
# Out:
# === SLDC Demand Stats (MW) ===
#            DELHI       BRPL       BYPL       NDPL       NDMC        MES
# count  430782.00  430782.00  430782.00  430782.00  430782.00  430782.00
# mean     4121.60    1754.60     882.36    1240.02     176.76      27.93
# std      1313.69     587.57     323.57     414.56      63.42       8.54
# min      1302.08     470.73     229.03 -124343.88       2.67       0.00
# 25%      3237.82    1349.61     676.79    1001.99     130.61      21.53
# 50%      4021.70    1695.80     857.73    1238.57     165.16      27.25
# 75%      5061.94    2166.56    1109.52    1501.52     207.23      33.50
# max      8631.53   64333.16   63516.52    2680.85     440.95      61.44
#
# === Missing Values ===
# DELHI    0
# BRPL     0
# BYPL     0
# NDPL     0
# NDMC     0
# MES      0
# dtype: int64
# Temperature (°C)             0
# Relative Humidity (%)        0
# Apparent Temperature (°C)    0
# Precipitation (mm)           0
# Wind Speed (m/s)             0
# Cloud Cover Total (%)        0
# dtype: int64

# %%
sldc['year']  = sldc['datetime'].dt.year
sldc['month'] = sldc['datetime'].dt.month
sldc['hour']  = sldc['datetime'].dt.hour
sldc['dow']   = sldc['datetime'].dt.dayofweek

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()
for i, r in enumerate(REGIONS):
    yearly = sldc.groupby('year')[r].mean()
    axes[i].bar(yearly.index, yearly.values, color=sns.color_palette('muted')[i], alpha=0.85)
    axes[i].set_title(f'{r} — Yearly Avg Demand (MW)', fontsize=11, fontweight='bold')
    axes[i].set_xlabel('Year'); axes[i].set_ylabel('Avg MW')
    for x, y in zip(yearly.index, yearly.values):
        axes[i].text(x, y+5, f'{y:.0f}', ha='center', fontsize=9)
plt.tight_layout()
plt.suptitle('Yearly Average Demand by Region', y=1.01, fontsize=14, fontweight='bold')
plt.savefig('01_yearly_demand.png', bbox_inches='tight')
plt.show()
print('Key insight: 2024 saw highest demand — likely due to extreme heat wave')
# Out:
# Key insight: 2024 saw highest demand — likely due to extreme heat wave

# %%
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
monthly = sldc.groupby('month')['DELHI'].mean()

fig, ax = plt.subplots(figsize=(14, 5))
colors = ['#c0392b' if m in [5,6,7,8,9] else '#2980b9' if m in [1,2,12] else '#27ae60' for m in range(1,13)]
bars = ax.bar(range(1,13), monthly.values, color=colors, alpha=0.85, width=0.7)
ax.set_xticks(range(1,13)); ax.set_xticklabels(months)
ax.set_ylabel('Avg Demand (MW)'); ax.set_title('Delhi Monthly Avg Demand — Clear Bimodal Pattern', fontsize=13, fontweight='bold')
from matplotlib.patches import Patch
legend = [Patch(color='#c0392b',label='High (Summer/Monsoon)'), Patch(color='#2980b9',label='Low (Winter)'), Patch(color='#27ae60',label='Transition')]
ax.legend(handles=legend)
for bar, v in zip(bars, monthly.values):
    ax.text(bar.get_x()+bar.get_width()/2, v+30, f'{v:.0f}', ha='center', fontsize=8)
plt.tight_layout()
plt.savefig('02_monthly_seasonality.png', bbox_inches='tight')
plt.show()
print('Peak months: Jun-Sep (AC + industrial load)')
print('Trough months: Feb-Mar, Nov')
# Out:
# Peak months: Jun-Sep (AC + industrial load)
# Trough months: Feb-Mar, Nov

# %%
def get_season(m):
    if m in [4,5,6]: return 'Summer'
    elif m in [7,8,9]: return 'Monsoon'
    elif m in [10,11,12,1,2]: return 'Winter'
    else: return 'Spring'

sldc['season'] = sldc['month'].apply(get_season)

fig, ax = plt.subplots(figsize=(14, 6))
palette = {'Summer':'#e74c3c','Monsoon':'#2ecc71','Winter':'#3498db','Spring':'#f39c12'}
for s, color in palette.items():
    sub = sldc[sldc['season']==s].groupby('hour')['DELHI'].mean()
    ax.plot(sub.index, sub.values, label=s, color=color, linewidth=2.5, marker='o', markersize=3)

ax.set_xlabel('Hour of Day'); ax.set_ylabel('Avg Demand (MW)')
ax.set_title('Delhi Hourly Demand Profile by Season', fontsize=13, fontweight='bold')
ax.set_xticks(range(24))
ax.axvspan(9,12, alpha=0.07, color='orange', label='Morning peak zone')
ax.axvspan(18,23, alpha=0.07, color='red', label='Evening peak zone')
ax.legend()
plt.tight_layout()
plt.savefig('03_hourly_profile.png', bbox_inches='tight')
plt.show()

print('Season-wise peak hours:')
for s in ['Summer','Monsoon','Winter']:
    sub = sldc[sldc['season']==s].groupby('hour')['DELHI'].mean()
    print(f"  {s}: Morning peak={sub[9:13].idxmax()}h, Evening peak={sub[17:23].idxmax()}h")
# Out:
# Season-wise peak hours:
#   Summer: Morning peak=12h, Evening peak=22h
#   Monsoon: Morning peak=12h, Evening peak=22h
#   Winter: Morning peak=10h, Evening peak=18h

# %%
sldc['date_str']   = sldc['datetime'].dt.strftime('%Y-%m-%d')
sldc['is_holiday'] = sldc['date_str'].isin(HOLIDAY_SET).astype(int)
sldc['is_weekend'] = (sldc['dow'] >= 5).astype(int)

def day_type(row):
    if row['is_holiday']:  return 'Holiday'
    elif row['is_weekend']: return 'Weekend'
    else: return 'Weekday'

sldc['day_type'] = sldc.apply(day_type, axis=1)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Box plot
order = ['Weekday','Weekend','Holiday']
colors_box = {'Weekday':'#3498db','Weekend':'#e67e22','Holiday':'#e74c3c'}
bp_data = [sldc[sldc['day_type']==d]['DELHI'].values for d in order]
bp = axes[0].boxplot(bp_data, labels=order, patch_artist=True, notch=True)
for patch, d in zip(bp['boxes'], order):
    patch.set_facecolor(colors_box[d])
    patch.set_alpha(0.7)
axes[0].set_ylabel('Demand (MW)')
axes[0].set_title('Demand Distribution: Weekday vs Weekend vs Holiday', fontweight='bold')

# Hourly profile comparison
for dt in order:
    sub = sldc[sldc['day_type']==dt].groupby('hour')['DELHI'].mean()
    axes[1].plot(sub.index, sub.values, label=dt, color=colors_box[dt], linewidth=2.5)
axes[1].set_xlabel('Hour'); axes[1].set_ylabel('Avg Demand (MW)')
axes[1].set_title('Hourly Profile: Day Type Comparison', fontweight='bold')
axes[1].legend(); axes[1].set_xticks(range(0,24,2))

plt.tight_layout()
plt.savefig('04_holiday_impact.png', bbox_inches='tight')
plt.show()

for dt in order:
    avg = sldc[sldc['day_type']==dt]['DELHI'].mean()
    print(f'{dt:10s}: {avg:.1f} MW avg')
wkd = sldc[sldc['day_type']=='Weekday']['DELHI'].mean()
hol = sldc[sldc['day_type']=='Holiday']['DELHI'].mean()
print(f'\n📉 Holiday reduces demand by {(1-hol/wkd)*100:.1f}% vs Weekday')
# Out:
# Weekday   : 4214.0 MW avg
# Weekend   : 3964.4 MW avg
# Holiday   : 3789.6 MW avg
#
# 📉 Holiday reduces demand by 10.1% vs Weekday

# %%
# Merge for correlation
wx_tmp = wx[['datetime','Temperature (°C)','Relative Humidity (%)','Apparent Temperature (°C)',
             'Precipitation (mm)','Wind Speed (m/s)','Cloud Cover Total (%)']].copy()
merged_tmp = pd.merge(sldc[['datetime','DELHI']], wx_tmp, on='datetime', how='inner')

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
# Temp vs Demand
sample = merged_tmp.sample(5000, random_state=42)
axes[0].scatter(sample['Temperature (°C)'], sample['DELHI'], alpha=0.2, s=3, c='#e74c3c')
axes[0].set_xlabel('Temperature (°C)'); axes[0].set_ylabel('DELHI Demand (MW)')
axes[0].set_title('Temperature vs Demand\n(Strong non-linear relationship)', fontweight='bold')

# Humidity vs Demand
axes[1].scatter(sample['Relative Humidity (%)'], sample['DELHI'], alpha=0.2, s=3, c='#2980b9')
axes[1].set_xlabel('Relative Humidity (%)'); axes[1].set_ylabel('DELHI Demand (MW)')
axes[1].set_title('Humidity vs Demand', fontweight='bold')

# Correlation heatmap
corr = merged_tmp[['DELHI','Temperature (°C)','Relative Humidity (%)','Apparent Temperature (°C)',
                    'Precipitation (mm)','Wind Speed (m/s)','Cloud Cover Total (%)']].corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='RdBu_r', center=0, ax=axes[2], cbar=True)
axes[2].set_title('Feature Correlation Matrix', fontweight='bold')

plt.tight_layout()
plt.savefig('05_weather_correlation.png', bbox_inches='tight')
plt.show()

print('Correlation with DELHI demand:')
print(corr['DELHI'].drop('DELHI').sort_values(ascending=False))
# Out:
# Correlation with DELHI demand:
# Apparent Temperature (°C)    0.756262
# Temperature (°C)             0.710027
# Cloud Cover Total (%)        0.197317
# Wind Speed (m/s)             0.150930
# Precipitation (mm)           0.060964
# Relative Humidity (%)       -0.208817
# Name: DELHI, dtype: float64

# %%
print('=== Outlier Analysis (1st–99th percentile method) ===')
OUTLIER_BOUNDS = {}
for r in REGIONS:
    q_low  = sldc[r].quantile(0.005)
    q_high = sldc[r].quantile(0.995)
    n_out  = ((sldc[r] < q_low) | (sldc[r] > q_high)).sum()
    OUTLIER_BOUNDS[r] = (q_low, q_high)
    pct = n_out/len(sldc)*100
    print(f'{r:6s}: [{q_low:.1f} – {q_high:.1f}] MW | Outliers: {n_out} ({pct:.2f}%)')

# Special case: BRPL has a single extreme spike (64333 MW on 2023-12-28)
print(f'\n⚠️  BRPL spike check: max={sldc["BRPL"].max():.1f} MW on',
      sldc.loc[sldc['BRPL'].idxmax(), 'datetime'])
# Out:
# === Outlier Analysis (1st–99th percentile method) ===
# DELHI : [1568.6 – 7443.9] MW | Outliers: 4308 (1.00%)
# BRPL  : [636.7 – 3308.6] MW | Outliers: 4307 (1.00%)
# BYPL  : [273.4 – 1639.2] MW | Outliers: 4308 (1.00%)
# NDPL  : [492.4 – 2132.5] MW | Outliers: 4306 (1.00%)
# NDMC  : [78.0 – 367.2] MW | Outliers: 4305 (1.00%)
# MES   : [12.6 – 51.5] MW | Outliers: 4277 (0.99%)
#
# ⚠️  BRPL spike check: max=64333.2 MW on 2023-12-28 17:30:00

# %%
# ── 5.1 Merge SLDC + Weather on datetime ──
wx_feats = wx[['datetime','Temperature (°C)','Relative Humidity (%)',
               'Apparent Temperature (°C)','Precipitation (mm)',
               'Wind Speed (m/s)','Cloud Cover Total (%)']].copy()
wx_feats.rename(columns={'Apparent Temperature (°C)':'feels_like'}, inplace=True)

df = pd.merge(sldc, wx_feats, on='datetime', how='inner')
print(f'Merged shape: {df.shape}')

# ── 5.2 Remove Outliers (Winsorize at 0.5–99.5%) ──
print('\nRemoving outliers...')
before = len(df)
for r in REGIONS:
    lo, hi = df[r].quantile(0.005), df[r].quantile(0.995)
    df[r] = df[r].clip(lo, hi)

# Remove the BRPL spike explicitly
df = df[df['BRPL'] < 10000].copy()
after = len(df)
print(f'Outliers handled: {before - after} rows removed/clipped')

# ── 5.3 Time Features ──
df['hour']        = df['datetime'].dt.hour
df['day_of_week'] = df['datetime'].dt.dayofweek
df['month']       = df['datetime'].dt.month
df['year']        = df['datetime'].dt.year
df['day_of_year'] = df['datetime'].dt.dayofyear
df['week_of_year']= df['datetime'].dt.isocalendar().week.astype(int)
df['date_str']    = df['datetime'].dt.strftime('%Y-%m-%d')
df['season']      = df['month'].apply(get_season)

# ── 5.4 Cyclic Features ──
df['hour_sin']  = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos']  = np.cos(2 * np.pi * df['hour'] / 24)
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
df['dow_sin']   = np.sin(2 * np.pi * df['day_of_week'] / 7)
df['dow_cos']   = np.cos(2 * np.pi * df['day_of_week'] / 7)

# ── 5.5 Flag Features ──
df['is_weekend'] = (df['day_of_week'] >= 5).astype(int)
df['is_holiday'] = df['date_str'].isin(HOLIDAY_SET).astype(int)
df['is_monsoon'] = df['month'].isin([7,8,9]).astype(int)
df['is_summer']  = df['month'].isin([4,5,6]).astype(int)
df['is_winter']  = df['month'].isin([10,11,12,1,2]).astype(int)

# ── 5.6 Season-Aware Peak Flags ──
# Based on EDA: summer/monsoon peaks 12h+22h, winter peaks 10h+18h
def is_morning_peak(row):
    h, s = row['hour'], row['season']
    if s == 'Winter': return int(9 <= h <= 11)
    elif s in ['Summer','Monsoon']: return int(11 <= h <= 13)
    else: return int(10 <= h <= 12)  # Spring

def is_evening_peak(row):
    h, s = row['hour'], row['season']
    if s == 'Winter': return int(17 <= h <= 19)
    elif s in ['Summer','Monsoon']: return int(20 <= h <= 23)
    else: return int(18 <= h <= 21)  # Spring

df['is_morning_peak'] = df.apply(is_morning_peak, axis=1)
df['is_evening_peak'] = df.apply(is_evening_peak, axis=1)

# ── 5.7 Year trend feature (normalized) ──
df['year_norm'] = (df['year'] - 2022) / 5  # 0 to 1 range

print('\n✅ Feature engineering complete')
print(f'Dataset shape: {df.shape}')
# Out:
# Merged shape: (430771, 24)
#
# Removing outliers...
# Outliers handled: 0 rows removed/clipped
#
# ✅ Feature engineering complete
# Dataset shape: (430771, 39)

# %%
# For prediction we need hourly output (matching Open-Meteo API)
# → Aggregate all 5-min slots into hourly means

df['hour_dt'] = df['datetime'].dt.floor('h')

agg_dict = {r: 'mean' for r in REGIONS}
agg_dict.update({
    'Temperature (°C)': 'mean',
    'Relative Humidity (%)': 'mean',
    'feels_like': 'mean',
    'Precipitation (mm)': 'sum',
    'Wind Speed (m/s)': 'mean',
    'Cloud Cover Total (%)': 'mean',
    'hour': 'first',
    'day_of_week': 'first',
    'month': 'first',
    'year': 'first',
    'day_of_year': 'first',
    'week_of_year': 'first',
    'year_norm': 'first',
    'hour_sin': 'first', 'hour_cos': 'first',
    'month_sin': 'first', 'month_cos': 'first',
    'dow_sin': 'first', 'dow_cos': 'first',
    'is_weekend': 'first',
    'is_holiday': 'first',
    'is_monsoon': 'first',
    'is_summer': 'first',
    'is_winter': 'first',
    'is_morning_peak': 'first',
    'is_evening_peak': 'first',
    'season': 'first',
    'date_str': 'first'
})

df_hourly = df.groupby('hour_dt').agg(agg_dict).reset_index()
df_hourly.rename(columns={'hour_dt':'datetime'}, inplace=True)

print(f'Hourly dataset: {df_hourly.shape}')
print(f'Date range: {df_hourly["datetime"].min()} → {df_hourly["datetime"].max()}')
print(f'Expected rows (4 years + ~4 months): ~{int((df_hourly.shape[0]))} hours')
# Out:
# Hourly dataset: (36193, 35)
# Date range: 2022-01-01 00:00:00 → 2026-04-01 23:00:00
# Expected rows (4 years + ~4 months): ~36193 hours

# %%
FEATURES = [
    # Time - Raw
    'hour', 'day_of_week', 'month', 'year', 'day_of_year', 'week_of_year', 'year_norm',
    # Time - Cyclic
    'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'dow_sin', 'dow_cos',
    # Season-aware peaks
    'is_morning_peak', 'is_evening_peak',
    # Flags
    'is_weekend', 'is_holiday', 'is_monsoon', 'is_summer', 'is_winter',
    # Weather
    'Temperature (°C)', 'Relative Humidity (%)', 'feels_like',
    'Precipitation (mm)', 'Wind Speed (m/s)', 'Cloud Cover Total (%)'
]

print(f'✅ Total features: {len(FEATURES)}')
for i, f in enumerate(FEATURES, 1):
    print(f'  {i:2d}. {f}')

# Verify all features exist
missing = [f for f in FEATURES if f not in df_hourly.columns]
if missing:
    print(f'\n❌ Missing features: {missing}')
else:
    print('\n✅ All features present in dataset')
# Out:
# ✅ Total features: 26
#    1. hour
#    2. day_of_week
#    3. month
#    4. year
#    5. day_of_year
#    6. week_of_year
#    7. year_norm
#    8. hour_sin
#    9. hour_cos
#   10. month_sin
#   11. month_cos
#   12. dow_sin
#   13. dow_cos
#   14. is_morning_peak
#   15. is_evening_peak
#   16. is_weekend
#   17. is_holiday
#   18. is_monsoon
#   19. is_summer
#   20. is_winter
#   21. Temperature (°C)
#   22. Relative Humidity (%)
#   23. feels_like
#   24. Precipitation (mm)
#   25. Wind Speed (m/s)
#   26. Cloud Cover Total (%)
#
# ✅ All features present in dataset

# %%
# 80/20 Train-Test Split (chronological, no shuffle)

split_idx = int(len(df_hourly) * 0.80)

train_df = df_hourly.iloc[:split_idx].copy()
test_df  = df_hourly.iloc[split_idx:].copy()

print(f'Train size: {len(train_df):,} hourly records ({train_df["datetime"].min().date()} → {train_df["datetime"].max().date()})')
print(f'Test  size: {len(test_df):,} hourly records ({test_df["datetime"].min().date()} → {test_df["datetime"].max().date()})')
print(f'\nTrain/Test split: {len(train_df)/(len(train_df)+len(test_df))*100:.1f}% / {len(test_df)/(len(train_df)+len(test_df))*100:.1f}%')

X_train = train_df[FEATURES]
X_test  = test_df[FEATURES]

print('\n✅ Split complete')
# Out:
# Train size: 28,954 hourly records (2022-01-01 → 2025-06-01)
# Test  size: 7,239 hourly records (2025-06-01 → 2026-04-01)
#
# Train/Test split: 80.0% / 20.0%
#
# ✅ Split complete

# %%
# ── Helper: Metrics ──
def compute_metrics(y_true, y_pred, region=''):
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
    r2   = r2_score(y_true, y_pred)
    acc  = 100 - mape  # accuracy as (100 - MAPE)
    return {'region': region, 'MAE': mae, 'RMSE': rmse, 'MAPE': mape, 'R2': r2, 'Accuracy': acc}

# Storage
all_models    = {}   # {region: {'xgb': model, 'lgb': model, 'cat': model}}
all_weights   = {}   # {region: {'xgb': w, 'lgb': w, 'cat': w}}
all_metrics   = []   # list of dicts
all_preds     = {}   # {region: y_pred_test_ensemble}

# Validation: use last 3 months of training data
val_cutoff = train_df['datetime'].max() - pd.DateOffset(months=3)
train_inner = train_df[train_df['datetime'] <= val_cutoff]
val_df      = train_df[train_df['datetime'] > val_cutoff]

X_train_inner = train_inner[FEATURES]
X_val         = val_df[FEATURES]

print(f'Inner train: {len(train_inner):,} | Validation: {len(val_df):,}')
print('\n' + '='*65)

for region in REGIONS:
    print(f'\n🔄 Training models for: {region}')
    
    y_train_inner = train_inner[region]
    y_val         = val_df[region]
    y_train_full  = train_df[region]
    y_test        = test_df[region]
    
    # ── XGBoost ──
    xgb_model = xgb.XGBRegressor(
        n_estimators      = 1200,
        learning_rate     = 0.04,
        max_depth         = 7,
        subsample         = 0.80,
        colsample_bytree  = 0.80,
        min_child_weight  = 5,
        reg_alpha         = 0.1,
        reg_lambda        = 1.5,
        gamma             = 0.05,
        random_state      = RANDOM_STATE,
        n_jobs            = -1,
        tree_method       = 'hist',
        early_stopping_rounds = 50,
        eval_metric       = 'mae'
    )
    xgb_model.fit(X_train_inner, y_train_inner,
                  eval_set=[(X_val, y_val)], verbose=False)
    xgb_val_pred  = xgb_model.predict(X_val)
    xgb_val_mae   = mean_absolute_error(y_val, xgb_val_pred)
    
    # Retrain on full training data
    xgb_final = xgb.XGBRegressor(
        n_estimators      = xgb_model.best_iteration + 50,
        learning_rate     = 0.04,
        max_depth         = 7,
        subsample         = 0.80,
        colsample_bytree  = 0.80,
        min_child_weight  = 5,
        reg_alpha         = 0.1,
        reg_lambda        = 1.5,
        gamma             = 0.05,
        random_state      = RANDOM_STATE,
        n_jobs            = -1,
        tree_method       = 'hist'
    )
    xgb_final.fit(X_train, y_train_full)
    print(f'  XGBoost  : best_iter={xgb_model.best_iteration}, val_MAE={xgb_val_mae:.2f}')
    
    # ── LightGBM ──
    lgb_model = lgb.LGBMRegressor(
        n_estimators      = 1500,
        learning_rate     = 0.03,
        num_leaves        = 63,
        max_depth         = -1,
        min_child_samples = 20,
        subsample         = 0.80,
        colsample_bytree  = 0.80,
        reg_alpha         = 0.1,
        reg_lambda        = 1.5,
        random_state      = RANDOM_STATE,
        n_jobs            = -1,
        verbose           = -1
    )
    lgb_model.fit(X_train_inner, y_train_inner,
                  eval_set=[(X_val, y_val)],
                  callbacks=[lgb.early_stopping(50, verbose=False), lgb.log_evaluation(-1)])
    lgb_val_pred = lgb_model.predict(X_val)
    lgb_val_mae  = mean_absolute_error(y_val, lgb_val_pred)
    
    lgb_final = lgb.LGBMRegressor(
        n_estimators      = lgb_model.best_iteration_ + 50,
        learning_rate     = 0.03,
        num_leaves        = 63,
        min_child_samples = 20,
        subsample         = 0.80,
        colsample_bytree  = 0.80,
        reg_alpha         = 0.1,
        reg_lambda        = 1.5,
        random_state      = RANDOM_STATE,
        n_jobs            = -1,
        verbose           = -1
    )
    lgb_final.fit(X_train, y_train_full)
    print(f'  LightGBM : best_iter={lgb_model.best_iteration_}, val_MAE={lgb_val_mae:.2f}')
    
    # ── CatBoost ──
    cat_model = CatBoostRegressor(
        iterations         = 1500,
        learning_rate      = 0.04,
        depth              = 7,
        l2_leaf_reg        = 3.0,
        subsample          = 0.80,
        colsample_bylevel  = 0.80,
        min_data_in_leaf   = 20,
        od_type            = 'Iter',
        od_wait            = 50,
        random_seed        = RANDOM_STATE,
        verbose            = 0
    )
    cat_model.fit(X_train_inner, y_train_inner,
                  eval_set=(X_val, y_val))
    cat_val_pred = cat_model.predict(X_val)
    cat_val_mae  = mean_absolute_error(y_val, cat_val_pred)
    
    cat_final = CatBoostRegressor(
        iterations         = cat_model.best_iteration_ + 50,
        learning_rate      = 0.04,
        depth              = 7,
        l2_leaf_reg        = 3.0,
        subsample          = 0.80,
        colsample_bylevel  = 0.80,
        min_data_in_leaf   = 20,
        random_seed        = RANDOM_STATE,
        verbose            = 0
    )
    cat_final.fit(X_train, y_train_full)
    print(f'  CatBoost : best_iter={cat_model.best_iteration_}, val_MAE={cat_val_mae:.2f}')
    
    # ── Compute Weighted Ensemble Weights ──
    # Weight = 1/MAE, normalized. Better model (lower MAE) → higher weight
    inv_maes = np.array([1/xgb_val_mae, 1/lgb_val_mae, 1/cat_val_mae])
    weights  = inv_maes / inv_maes.sum()
    all_weights[region] = {'xgb': weights[0], 'lgb': weights[1], 'cat': weights[2]}
    print(f'  Ensemble weights → XGB:{weights[0]:.3f}, LGB:{weights[1]:.3f}, CAT:{weights[2]:.3f}')
    
    # ── Test Predictions ──
    xgb_test = xgb_final.predict(X_test)
    lgb_test = lgb_final.predict(X_test)
    cat_test = cat_final.predict(X_test)
    ensemble_test = weights[0]*xgb_test + weights[1]*lgb_test + weights[2]*cat_test
    
    all_preds[region] = ensemble_test
    all_models[region] = {'xgb': xgb_final, 'lgb': lgb_final, 'cat': cat_final}
    
    # Metrics
    m_xgb = compute_metrics(y_test, xgb_test, f'{region}_XGB')
    m_lgb = compute_metrics(y_test, lgb_test, f'{region}_LGB')
    m_cat = compute_metrics(y_test, cat_test, f'{region}_CAT')
    m_ens = compute_metrics(y_test, ensemble_test, f'{region}_ENSEMBLE')
    all_metrics.extend([m_xgb, m_lgb, m_cat, m_ens])
    print(f'  ✅ Ensemble Test Accuracy: {m_ens["Accuracy"]:.2f}% | MAPE: {m_ens["MAPE"]:.2f}%')

print('\n' + '='*65)
print('✅ Training complete for all regions!')
# Out:
# Inner train: 26,758 | Validation: 2,196
#
# =================================================================
#
# 🔄 Training models for: DELHI
#   XGBoost  : best_iter=219, val_MAE=251.90
#   LightGBM : best_iter=805, val_MAE=253.66
#   CatBoost : best_iter=509, val_MAE=244.70
#   Ensemble weights → XGB:0.331, LGB:0.329, CAT:0.341
#   ✅ Ensemble Test Accuracy: 92.70% | MAPE: 7.30%
#
# 🔄 Training models for: BRPL
#   XGBoost  : best_iter=77, val_MAE=120.14
#   LightGBM : best_iter=124, val_MAE=123.32
#   CatBoost : best_iter=444, val_MAE=115.07
#   Ensemble weights → XGB:0.331, LGB:0.323, CAT:0.346
#   ✅ Ensemble Test Accuracy: 92.77% | MAPE: 7.23%
#
# 🔄 Training models for: BYPL
#   XGBoost  : best_iter=60, val_MAE=67.76
#   LightGBM : best_iter=72, val_MAE=71.83
#   CatBoost : best_iter=48, val_MAE=73.71
#   Ensemble weights → XGB:0.349, LGB:0.330, CAT:0.321
#   ✅ Ensemble Test Accuracy: 91.68% | MAPE: 8.32%
#
# 🔄 Training models for: NDPL
#   XGBoost  : best_iter=253, val_MAE=75.38
#   LightGBM : best_iter=216, val_MAE=81.46
#   CatBoost : best_iter=360, val_MAE=76.16
#   Ensemble weights → XGB:0.343, LGB:0.317, CAT:0.340
#   ✅ Ensemble Test Accuracy: 91.94% | MAPE: 8.06%
#
# 🔄 Training models for: NDMC
#   XGBoost  : best_iter=166, val_MAE=11.75
#   LightGBM : best_iter=249, val_MAE=11.95
#   CatBoost : best_iter=227, val_MAE=11.97
#   Ensemble weights → XGB:0.337, LGB:0.332, CAT:0.331
#   ✅ Ensemble Test Accuracy: 88.44% | MAPE: 11.56%
#
# 🔄 Training models for: MES
#   XGBoost  : best_iter=262, val_MAE=1.95
#   LightGBM : best_iter=545, val_MAE=1.96
#   CatBoost : best_iter=454, val_MAE=1.99
#   Ensemble weights → XGB:0.336, LGB:0.334, CAT:0.330
#   ✅ Ensemble Test Accuracy: 89.85% | MAPE: 10.15%
#
# =================================================================
# ✅ Training complete for all regions!

# %%
metrics_df = pd.DataFrame(all_metrics)
metrics_df = metrics_df.round({'MAE':2, 'RMSE':2, 'MAPE':3, 'R2':4, 'Accuracy':3})

print('=== FULL METRICS TABLE ===')
print(metrics_df.to_string(index=False))

print('\n=== ENSEMBLE ONLY — ALL REGIONS ===')
ens_only = metrics_df[metrics_df['region'].str.contains('ENSEMBLE')].copy()
ens_only['region'] = ens_only['region'].str.replace('_ENSEMBLE','')
print(ens_only.to_string(index=False))
# Out:
# === FULL METRICS TABLE ===
#         region    MAE   RMSE   MAPE     R2  Accuracy
#      DELHI_XGB 301.34 382.23  7.393 0.9162    92.607
#      DELHI_LGB 311.30 392.66  7.574 0.9116    92.426
#      DELHI_CAT 289.78 367.43  7.197 0.9226    92.803
# DELHI_ENSEMBLE 296.87 374.56  7.301 0.9195    92.699
#       BRPL_XGB 133.56 171.76  7.359 0.9074    92.641
#       BRPL_LGB 132.84 172.31  7.345 0.9068    92.655
#       BRPL_CAT 129.12 166.18  7.280 0.9133    92.720
#  BRPL_ENSEMBLE 130.07 167.62  7.230 0.9118    92.770
#       BYPL_XGB  74.07  97.02  8.364 0.9073    91.636
#       BYPL_LGB  76.63 100.41  8.574 0.9007    91.426
#       BYPL_CAT  73.16  94.27  8.685 0.9125    91.315
#  BYPL_ENSEMBLE  73.15  95.25  8.320 0.9106    91.680
#       NDPL_XGB  95.51 125.96  8.155 0.8887    91.845
#       NDPL_LGB  97.73 128.87  8.286 0.8835    91.714
#       NDPL_CAT  93.65 124.45  8.035 0.8914    91.965
#  NDPL_ENSEMBLE  94.46 124.82  8.064 0.8907    91.936
#       NDMC_XGB  22.01  27.56 11.964 0.8006    88.036
#       NDMC_LGB  21.55  27.38 11.635 0.8032    88.365
#       NDMC_CAT  20.99  26.81 11.272 0.8113    88.728
#  NDMC_ENSEMBLE  21.39  27.06 11.555 0.8078    88.445
#        MES_XGB   2.74   3.50 10.392 0.8037    89.608
#        MES_LGB   2.74   3.48 10.415 0.8055    89.585
#        MES_CAT   2.62   3.33  9.979 0.8226    90.021
#   MES_ENSEMBLE   2.67   3.40 10.151 0.8150    89.849
#
# === ENSEMBLE ONLY — ALL REGIONS ===
# region    MAE   RMSE   MAPE     R2  Accuracy
#  DELHI 296.87 374.56  7.301 0.9195    92.699
#   BRPL 130.07 167.62  7.230 0.9118    92.770
#   BYPL  73.15  95.25  8.320 0.9106    91.680
#   NDPL  94.46 124.82  8.064 0.8907    91.936
#   NDMC  21.39  27.06 11.555 0.8078    88.445
#    MES   2.67   3.40 10.151 0.8150    89.849

# %%
# ── Actual vs Predicted Demand (after training complete) ──

actual_vs_pred = {}

for region in REGIONS:
    y_actual = test_df[region].values
    y_pred   = all_preds[region]

    result_df = pd.DataFrame({
        'datetime': test_df['datetime'].values,
        'Actual_Demand': y_actual,
        'Predicted_Demand': np.round(y_pred, 2),
        'Error': np.round(y_actual - y_pred, 2),
        'Abs_Error': np.round(np.abs(y_actual - y_pred), 2)
    })

    actual_vs_pred[region] = result_df

    print(f"\n=== {region} : Actual vs Predicted ===")
    print(result_df.head(10).to_string(index=False))

print("\n✅ Stored in dictionary: actual_vs_pred['DELHI'], actual_vs_pred['BRPL'] etc.")
# Out:
# === DELHI : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand   Error  Abs_Error
# 2025-06-01 08:00:00    3980.052500           4370.34 -390.29     390.29
# 2025-06-01 09:00:00    4145.115000           4632.14 -487.03     487.03
# 2025-06-01 10:00:00    4340.500833           4653.42 -312.92     312.92
# 2025-06-01 11:00:00    4590.401667           4785.46 -195.06     195.06
# 2025-06-01 12:00:00    4879.020000           5062.59 -183.57     183.57
# 2025-06-01 13:00:00    5029.610000           5172.13 -142.52     142.52
# 2025-06-01 14:00:00    5434.582500           5285.14  149.44     149.44
# 2025-06-01 15:00:00    5653.434167           5530.71  122.72     122.72
# 2025-06-01 16:00:00    5176.654167           5401.09 -224.44     224.44
# 2025-06-01 17:00:00    4216.321667           4815.40 -599.08     599.08
#
# === BRPL : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand   Error  Abs_Error
# 2025-06-01 08:00:00    1759.715000           2040.46 -280.74     280.74
# 2025-06-01 09:00:00    1781.666667           2086.92 -305.26     305.26
# 2025-06-01 10:00:00    1832.644167           2093.33 -260.69     260.69
# 2025-06-01 11:00:00    1944.353333           2141.77 -197.42     197.42
# 2025-06-01 12:00:00    2073.100833           2252.91 -179.81     179.81
# 2025-06-01 13:00:00    2186.486667           2324.12 -137.63     137.63
# 2025-06-01 14:00:00    2338.127500           2320.87   17.26      17.26
# 2025-06-01 15:00:00    2426.870000           2432.98   -6.11       6.11
# 2025-06-01 16:00:00    2117.994167           2400.05 -282.06     282.06
# 2025-06-01 17:00:00    1748.980833           2143.68 -394.70     394.70
#
# === BYPL : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand   Error  Abs_Error
# 2025-06-01 08:00:00     871.087500            997.67 -126.58     126.58
# 2025-06-01 09:00:00     904.310833           1009.52 -105.21     105.21
# 2025-06-01 10:00:00     945.887500           1039.49  -93.60      93.60
# 2025-06-01 11:00:00     992.645833           1096.63 -103.98     103.98
# 2025-06-01 12:00:00    1052.513333           1161.15 -108.63     108.63
# 2025-06-01 13:00:00    1091.108333           1188.71  -97.61      97.61
# 2025-06-01 14:00:00    1186.224167           1198.07  -11.85      11.85
# 2025-06-01 15:00:00    1249.779167           1240.76    9.02       9.02
# 2025-06-01 16:00:00    1188.324167           1222.30  -33.98      33.98
# 2025-06-01 17:00:00     901.882500           1140.14 -238.26     238.26
#
# === NDPL : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand   Error  Abs_Error
# 2025-06-01 08:00:00    1116.690833           1247.24 -130.55     130.55
# 2025-06-01 09:00:00    1201.015000           1328.38 -127.37     127.37
# 2025-06-01 10:00:00    1292.858333           1387.76  -94.90      94.90
# 2025-06-01 11:00:00    1378.005833           1469.61  -91.60      91.60
# 2025-06-01 12:00:00    1469.525833           1565.08  -95.56      95.56
# 2025-06-01 13:00:00    1462.085000           1515.45  -53.37      53.37
# 2025-06-01 14:00:00    1610.568333           1580.96   29.61      29.61
# 2025-06-01 15:00:00    1669.162500           1638.98   30.18      30.18
# 2025-06-01 16:00:00    1569.390833           1607.62  -38.23      38.23
# 2025-06-01 17:00:00    1292.170000           1442.34 -150.17     150.17
#
# === NDMC : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand  Error  Abs_Error
# 2025-06-01 08:00:00     171.540833            166.40   5.14       5.14
# 2025-06-01 09:00:00     195.162500            172.06  23.10      23.10
# 2025-06-01 10:00:00     203.021667            175.91  27.11      27.11
# 2025-06-01 11:00:00     204.974167            181.78  23.19      23.19
# 2025-06-01 12:00:00     209.015000            186.10  22.92      22.92
# 2025-06-01 13:00:00     212.740833            189.89  22.85      22.85
# 2025-06-01 14:00:00     217.424167            186.56  30.87      30.87
# 2025-06-01 15:00:00     223.920000            194.41  29.51      29.51
# 2025-06-01 16:00:00     221.917500            192.26  29.66      29.66
# 2025-06-01 17:00:00     208.327500            185.42  22.90      22.90
#
# === MES : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand  Error  Abs_Error
# 2025-06-01 08:00:00      23.480000             25.40  -1.92       1.92
# 2025-06-01 09:00:00      25.195833             26.36  -1.17       1.17
# 2025-06-01 10:00:00      24.749167             25.69  -0.94       0.94
# 2025-06-01 11:00:00      26.904167             26.32   0.59       0.59
# 2025-06-01 12:00:00      28.256667             27.56   0.69       0.69
# 2025-06-01 13:00:00      29.266667             28.06   1.21       1.21
# 2025-06-01 14:00:00      30.060000             26.58   3.48       3.48
# 2025-06-01 15:00:00      30.092500             28.05   2.04       2.04
# 2025-06-01 16:00:00      28.352500             28.23   0.12       0.12
# 2025-06-01 17:00:00      24.964167             26.81  -1.85       1.85
#
# ✅ Stored in dictionary: actual_vs_pred['DELHI'], actual_vs_pred['BRPL'] etc.

# %%
y_actual = test_df["DELHI"].values
y_pred   = all_preds["DELHI"]

result_df = pd.DataFrame({
    'datetime': test_df['datetime'].values,
    'Actual_Demand': y_actual,
    'Predicted_Demand': np.round(y_pred, 2),
    'Error': np.round(y_actual - y_pred, 2),
    'Abs_Error': np.round(np.abs(y_actual - y_pred), 2)
})

actual_vs_pred["DELHI"] = result_df

print(f"\n=== DELHI : Actual vs Predicted ===")
print(result_df.to_string(index=False))
# Out:
# === DELHI : Actual vs Predicted ===
#            datetime  Actual_Demand  Predicted_Demand    Error  Abs_Error
# 2025-06-01 08:00:00    3980.052500           4370.34  -390.29     390.29
# 2025-06-01 09:00:00    4145.115000           4632.14  -487.03     487.03
# 2025-06-01 10:00:00    4340.500833           4653.42  -312.92     312.92
# 2025-06-01 11:00:00    4590.401667           4785.46  -195.06     195.06
# 2025-06-01 12:00:00    4879.020000           5062.59  -183.57     183.57
# 2025-06-01 13:00:00    5029.610000           5172.13  -142.52     142.52
# 2025-06-01 14:00:00    5434.582500           5285.14   149.44     149.44
# 2025-06-01 15:00:00    5653.434167           5530.71   122.72     122.72
# 2025-06-01 16:00:00    5176.654167           5401.09  -224.44     224.44
# 2025-06-01 17:00:00    4216.321667           4815.40  -599.08     599.08
# 2025-06-01 18:00:00    4384.110000           4624.73  -240.62     240.62
# 2025-06-01 19:00:00    4532.915000           4763.15  -230.24     230.24
# 2025-06-01 20:00:00    4574.135833           4816.90  -242.76     242.76
# 2025-06-01 21:00:00    4754.025833           4944.07  -190.05     190.05
# 2025-06-01 22:00:00    5079.249167           5408.70  -329.45     329.45
# 2025-06-01 23:00:00    5316.704444           5572.12  -255.42     255.42
# 2025-06-02 00:00:00    5185.737500           5726.00  -540.26     540.26
# 2025-06-02 01:00:00    4896.303333           5469.74  -573.44     573.44
# 2025-06-02 02:00:00    4642.062500           5091.50  -449.44     449.44
# 2025-06-02 03:00:00    4397.812500           4444.97   -47.15      47.15
# 2025-06-02 04:00:00    4216.243333           4235.48   -19.24      19.24
# 2025-06-02 05:00:00    4102.960000           4287.40  -184.44     184.44
# 2025-06-02 06:00:00    4036.772500           4446.71  -409.94     409.94
# 2025-06-02 07:00:00    4090.825000           4443.60  -352.77     352.77
# 2025-06-02 08:00:00    4207.106667           4553.77  -346.67     346.67
# 2025-06-02 09:00:00    4627.699167           4849.87  -222.17     222.17
# 2025-06-02 10:00:00    5120.751667           5383.66  -262.91     262.91
# 2025-06-02 11:00:00    5287.947500           5798.05  -510.11     510.11
# 2025-06-02 12:00:00    5321.403333           5937.41  -616.01     616.01
# 2025-06-02 13:00:00    5451.321667           5822.47  -371.15     371.15
# 2025-06-02 14:00:00    5718.730833           5976.40  -257.67     257.67
# 2025-06-02 15:00:00    5610.384167           6106.10  -495.71     495.71
# 2025-06-02 16:00:00    5650.269167           5925.97  -275.70     275.70
# 2025-06-02 17:00:00    5392.275833           5648.27  -256.00     256.00
# 2025-06-02 18:00:00    5143.399167           5471.22  -327.82     327.82
# 2025-06-02 19:00:00    5020.810000           5433.13  -412.32     412.32
# 2025-06-02 20:00:00    4935.084167           5498.94  -563.86     563.86
# 2025-06-02 21:00:00    5033.317500           5514.94  -481.62     481.62
# 2025-06-02 22:00:00    5343.306667           5725.26  -381.95     381.95
# 2025-06-02 23:00:00    5561.947273           5934.57  -372.63     372.63
# 2025-06-03 00:00:00    5419.154167           5756.07  -336.92     336.92
# 2025-06-03 01:00:00    5114.564167           5489.57  -375.00     375.00
# 2025-06-03 02:00:00    4806.900833           5222.09  -415.18     415.18
# 2025-06-03 03:00:00    4566.687500           4944.74  -378.05     378.05
# 2025-06-03 04:00:00    4332.055833           4608.93  -276.87     276.87
# 2025-06-03 05:00:00    4121.957500           4181.06   -59.10      59.10
# 2025-06-03 06:00:00    4013.760833           4289.72  -275.96     275.96
# 2025-06-03 07:00:00    3914.885000           4285.02  -370.14     370.14
# 2025-06-03 08:00:00    3941.337500           4406.48  -465.14     465.14
# 2025-06-03 09:00:00    4343.899167           4794.78  -450.88     450.88
# 2025-06-03 10:00:00    4886.078333           5375.31  -489.23     489.23
# 2025-06-03 11:00:00    5041.752500           5700.57  -658.82     658.82
# 2025-06-03 12:00:00    5150.127500           5699.25  -549.12     549.12
# 2025-06-03 13:00:00    5034.810833           5648.11  -613.30     613.30
# 2025-06-03 14:00:00    5154.838333           5799.40  -644.56     644.56
# 2025-06-03 15:00:00    5200.098333           5779.02  -578.92     578.92
# 2025-06-03 16:00:00    5280.869167           5752.88  -472.01     472.01
# 2025-06-03 17:00:00    5185.173333           5496.14  -310.96     310.96
# 2025-06-03 18:00:00    4988.666667           5159.58  -170.91     170.91
# 2025-06-03 19:00:00    4921.935833           5227.20  -305.26     305.26
# 2025-06-03 20:00:00    4947.195833           5257.30  -310.10     310.10
# 2025-06-03 21:00:00    5071.952500           5306.03  -234.07     234.07
# 2025-06-03 22:00:00    5310.817500           5420.27  -109.45     109.45
# 2025-06-03 23:00:00    5306.246364           5304.29     1.96       1.96
# 2025-06-04 00:00:00    5139.070833           5076.91    62.16      62.16
# 2025-06-04 01:00:00    4857.081667           4845.03    12.05      12.05
# 2025-06-04 02:00:00    4579.935833           4662.67   -82.74      82.74
# 2025-06-04 03:00:00    4351.638333           4399.23   -47.59      47.59
# 2025-06-04 04:00:00    4160.150000           4262.15  -102.00     102.00
# 2025-06-04 05:00:00    4007.985000           4244.39  -236.40     236.40
# 2025-06-04 06:00:00    3954.872500           4300.62  -345.75     345.75
# 2025-06-04 07:00:00    3981.229167           4251.21  -269.98     269.98
# 2025-06-04 08:00:00    3935.555000           4283.97  -348.42     348.42
# 2025-06-04 09:00:00    4254.196667           4599.40  -345.20     345.20
# 2025-06-04 10:00:00    4784.961667           5191.78  -406.82     406.82
# 2025-06-04 11:00:00    5000.724167           5529.83  -529.10     529.10
# 2025-06-04 12:00:00    5097.448333           5807.69  -710.24     710.24
# 2025-06-04 13:00:00    5040.552500           5551.47  -510.92     510.92
# 2025-06-04 14:00:00    5290.335000           5204.59    85.75      85.75
# 2025-06-04 15:00:00    5499.050000           5386.76   112.29     112.29
# 2025-06-04 16:00:00    5499.050000           5466.65    32.40      32.40
# 2025-06-04 17:00:00    5499.050000           5419.74    79.31      79.31
# 2025-06-04 18:00:00    5499.050000           5261.60   237.45     237.45
# 2025-06-04 19:00:00    5499.050000           5197.21   301.84     301.84
# 2025-06-04 20:00:00    5499.050000           5139.09   359.96     359.96
# 2025-06-04 21:00:00    5499.050000           4960.62   538.43     538.43
# 2025-06-04 22:00:00    5499.050000           5126.68   372.37     372.37
# 2025-06-04 23:00:00    5499.050000           5225.98   273.07     273.07
# 2025-06-05 00:00:00    5499.050000           5111.62   387.43     387.43
# 2025-06-05 01:00:00    5499.050000           4826.38   672.67     672.67
# 2025-06-05 02:00:00    5499.050000           4504.34   994.71     994.71
# 2025-06-05 03:00:00    5499.050000           4194.00  1305.05    1305.05
# 2025-06-05 04:00:00    5499.050000           4039.94  1459.11    1459.11
# 2025-06-05 05:00:00    5499.050000           4140.18  1358.87    1358.87
# 2025-06-05 06:00:00    5499.050000           4313.76  1185.29    1185.29
# 2025-06-05 07:00:00    5499.050000           4367.05  1132.00    1132.00
# 2025-06-05 08:00:00    5499.050000           4458.71  1040.34    1040.34
# 2025-06-05 09:00:00    5499.050000           4733.27   765.78     765.78
# 2025-06-05 10:00:00    5499.050000           5208.75   290.30     290.30
# 2025-06-05 11:00:00    5499.050000           5536.15   -37.10      37.10
# 2025-06-05 12:00:00    5499.050000           5728.44  -229.39     229.39
# 2025-06-05 13:00:00    5499.050000           5801.29  -302.24     302.24
# 2025-06-05 14:00:00    5499.050000           6011.48  -512.43     512.43
# 2025-06-05 15:00:00    5499.050000           6176.64  -677.59     677.59
# 2025-06-05 16:00:00    5499.050000           5965.70  -466.65     466.65
# 2025-06-05 17:00:00    5499.050000           5871.67  -372.62     372.62
# 2025-06-05 18:00:00    5499.050000           5490.26     8.79       8.79
# 2025-06-05 19:00:00    5499.050000           5365.45   133.60     133.60
# 2025-06-05 20:00:00    5499.050000           5444.75    54.30      54.30
# 2025-06-05 21:00:00    5499.050000           5577.45   -78.40      78.40
# 2025-06-05 22:00:00    5499.050000           5877.40  -378.35     378.35
# 2025-06-05 23:00:00    5499.050000           6006.73  -507.68     507.68
# 2025-06-06 00:00:00    5849.000000           5779.57    69.43      69.43
# 2025-06-06 01:00:00    5849.000000           5392.51   456.49     456.49
# 2025-06-06 02:00:00    5849.000000           5182.29   666.71     666.71
# 2025-06-06 03:00:00    5849.000000           4838.23  1010.77    1010.77
# 2025-06-06 04:00:00    5849.000000           4575.40  1273.60    1273.60
# 2025-06-06 05:00:00    5849.000000           4554.72  1294.28    1294.28
# 2025-06-06 06:00:00    5849.000000           4570.56  1278.44    1278.44
# 2025-06-06 07:00:00    5421.000000           4588.24   832.76     832.76
# 2025-06-06 08:00:00    4137.000000           4678.57  -541.57     541.57
# 2025-06-06 09:00:00    4137.000000           5027.87  -890.87     890.87
# 2025-06-06 10:00:00    4137.000000           5514.54 -1377.54    1377.54
# 2025-06-06 11:00:00    4137.000000           5840.98 -1703.98    1703.98
# 2025-06-06 12:00:00    4137.000000           6066.20 -1929.20    1929.20
# 2025-06-06 13:00:00    5009.378333           6183.11 -1173.73    1173.73
# 2025-06-06 14:00:00    5941.777500           6498.73  -556.96     556.96
# 2025-06-06 15:00:00    6096.954167           6420.68  -323.73     323.73
# 2025-06-06 16:00:00    5990.533333           6329.53  -339.00     339.00
# 2025-06-06 17:00:00    5768.713333           6060.05  -291.34     291.34
# 2025-06-06 18:00:00    5426.150833           5743.08  -316.92     316.92
# 2025-06-06 19:00:00    5281.751667           5627.50  -345.75     345.75
# 2025-06-06 20:00:00    5293.194167           5640.52  -347.32     347.32
# 2025-06-06 21:00:00    5479.475833           5737.54  -258.07     258.07
# 2025-06-06 22:00:00    5874.484167           6056.76  -182.28     182.28
# 2025-06-06 23:00:00    6094.558182           6243.17  -148.61     148.61
# 2025-06-07 00:00:00    5923.411667           6085.03  -161.62     161.62
# 2025-06-07 01:00:00    5623.675833           5771.00  -147.32     147.32
# 2025-06-07 02:00:00    5294.899167           5527.31  -232.41     232.41
# 2025-06-07 03:00:00    5024.653333           5183.03  -158.38     158.38
# 2025-06-07 04:00:00    4818.160833           4887.87   -69.70      69.70
# 2025-06-07 05:00:00    4609.862500           4732.35  -122.49     122.49
# 2025-06-07 06:00:00    4440.329167           4681.77  -241.44     241.44
# 2025-06-07 07:00:00    4346.378333           4631.56  -285.18     285.18
# 2025-06-07 08:00:00    4301.290000           4696.07  -394.78     394.78
# 2025-06-07 09:00:00    4558.224167           4932.76  -374.54     374.54
# 2025-06-07 10:00:00    4987.858333           5344.66  -356.80     356.80
# 2025-06-07 11:00:00    5235.915833           5613.73  -377.81     377.81
# 2025-06-07 12:00:00    5468.380833           5895.51  -427.13     427.13
# 2025-06-07 13:00:00    5561.771667           5783.98  -222.21     222.21
# 2025-06-07 14:00:00    5902.200000           6090.49  -188.29     188.29
# 2025-06-07 15:00:00    6085.243333           6199.29  -114.05     114.05
# 2025-06-07 16:00:00    5939.288333           6100.18  -160.90     160.90
# 2025-06-07 17:00:00    5696.841667           5711.43   -14.59      14.59
# 2025-06-07 18:00:00    5399.882500           5518.55  -118.67     118.67
# 2025-06-07 19:00:00    5362.693333           5410.96   -48.27      48.27
# 2025-06-07 20:00:00    5601.376667           5532.12    69.25      69.25
# 2025-06-07 21:00:00    5928.363333           5772.46   155.91     155.91
# 2025-06-07 22:00:00    6344.659167           6155.38   189.28     189.28
# 2025-06-07 23:00:00    6539.670000           6368.58   171.09     171.09
# 2025-06-08 00:00:00    6366.941667           6343.79    23.16      23.16
# 2025-06-08 01:00:00    6037.603333           6050.99   -13.39      13.39
# 2025-06-08 02:00:00    5712.163333           5781.54   -69.38      69.38
# 2025-06-08 03:00:00    5423.508333           5385.15    38.35      38.35
# 2025-06-08 04:00:00    5165.665833           5036.88   128.78     128.78
# 2025-06-08 05:00:00    4895.390833           4882.83    12.57      12.57
# 2025-06-08 06:00:00    4667.540000           4636.70    30.84      30.84
# 2025-06-08 07:00:00    4521.715833           4489.79    31.92      31.92
# 2025-06-08 08:00:00    4397.335833           4456.45   -59.11      59.11
# 2025-06-08 09:00:00    4438.119167           4765.77  -327.65     327.65
# 2025-06-08 10:00:00    4668.920833           5186.27  -517.35     517.35
# 2025-06-08 11:00:00    5123.375833           5391.44  -268.06     268.06
# 2025-06-08 12:00:00    5388.795833           5745.78  -356.98     356.98
# 2025-06-08 13:00:00    5598.026667           5947.56  -349.54     349.54
# 2025-06-08 14:00:00    5981.818333           6359.62  -377.80     377.80
# 2025-06-08 15:00:00    6181.208333           6511.45  -330.24     330.24
# 2025-06-08 16:00:00    6040.148333           6418.81  -378.66     378.66
# 2025-06-08 17:00:00    5729.244167           6240.94  -511.69     511.69
# 2025-06-08 18:00:00    5444.948333           6086.73  -641.78     641.78
# 2025-06-08 19:00:00    5498.672500           5935.77  -437.09     437.09
# 2025-06-08 20:00:00    5825.059167           6022.75  -197.69     197.69
# 2025-06-08 21:00:00    6288.159167           6134.10   154.06     154.06
# 2025-06-08 22:00:00    6636.379167           6275.02   361.35     361.35
# 2025-06-08 23:00:00    6990.843000           6445.01   545.83     545.83
# 2025-06-09 00:00:00    6739.307500           6674.14    65.17      65.17
# 2025-06-09 01:00:00    6531.842500           6673.89  -142.04     142.04
# 2025-06-09 02:00:00    6209.725000           6337.93  -128.21     128.21
# 2025-06-09 03:00:00    5869.537500           5780.57    88.97      88.97
# 2025-06-09 04:00:00    5557.235833           5446.54   110.70     110.70
# 2025-06-09 05:00:00    5220.894167           5270.08   -49.18      49.18
# 2025-06-09 06:00:00    4953.360000           5194.53  -241.17     241.17
# 2025-06-09 07:00:00    4881.700000           5128.66  -246.96     246.96
# 2025-06-09 08:00:00    4898.282500           5309.23  -410.95     410.95
# 2025-06-09 09:00:00    5320.990000           5652.62  -331.63     331.63
# 2025-06-09 10:00:00    5870.375833           6167.89  -297.52     297.52
# 2025-06-09 11:00:00    6210.045000           6480.56  -270.52     270.52
# 2025-06-09 12:00:00    6487.329167           6629.74  -142.41     142.41
# 2025-06-09 13:00:00    6673.572500           6791.80  -118.23     118.23
# 2025-06-09 14:00:00    7017.370833           7160.33  -142.96     142.96
# 2025-06-09 15:00:00    7286.776667           7268.24    18.54      18.54
# 2025-06-09 16:00:00    7139.724167           7178.81   -39.09      39.09
# 2025-06-09 17:00:00    6764.146667           6998.40  -234.25     234.25
# 2025-06-09 18:00:00    6236.020833           6661.90  -425.87     425.87
# 2025-06-09 19:00:00    5947.750000           6544.23  -596.48     596.48
# 2025-06-09 20:00:00    6033.215833           6479.61  -446.40     446.40
# 2025-06-09 21:00:00    6435.795000           6676.33  -240.53     240.53
# 2025-06-09 22:00:00    7025.285000           7042.63   -17.34      17.34
# 2025-06-09 23:00:00    7313.678000           7167.63   146.05     146.05
# 2025-06-10 00:00:00    7093.625833           7028.29    65.34      65.34
# 2025-06-10 01:00:00    6745.004167           6799.15   -54.15      54.15
# 2025-06-10 02:00:00    6379.936667           6486.64  -106.70     106.70
# 2025-06-10 03:00:00    6036.542500           5953.63    82.91      82.91
# 2025-06-10 04:00:00    5691.719167           5647.80    43.92      43.92
# 2025-06-10 05:00:00    5303.321667           5397.91   -94.59      94.59
# 2025-06-10 06:00:00    5027.968333           5228.93  -200.97     200.97
# 2025-06-10 07:00:00    4931.276667           5072.60  -141.32     141.32
# 2025-06-10 08:00:00    4991.636667           5130.28  -138.64     138.64
# 2025-06-10 09:00:00    5366.264167           5473.47  -107.20     107.20
# 2025-06-10 10:00:00    5869.885833           6008.56  -138.67     138.67
# 2025-06-10 11:00:00    6175.354167           6433.79  -258.44     258.44
# 2025-06-10 12:00:00    6402.585833           6627.50  -224.91     224.91
# 2025-06-10 13:00:00    6457.210000           6824.49  -367.28     367.28
# 2025-06-11 00:00:00    7200.064167           6901.91   298.16     298.16
# 2025-06-11 01:00:00    6848.134167           6689.21   158.92     158.92
# 2025-06-11 02:00:00    6513.465000           6293.60   219.86     219.86
# 2025-06-11 03:00:00    6179.690833           5823.98   355.71     355.71
# 2025-06-11 04:00:00    5867.352500           5529.56   337.80     337.80
# 2025-06-11 05:00:00    5532.959167           5459.79    73.17      73.17
# 2025-06-11 06:00:00    5214.707500           5296.19   -81.48      81.48
# 2025-06-11 07:00:00    5080.701667           5113.53   -32.83      32.83
# 2025-06-11 08:00:00    5091.685000           5147.43   -55.74      55.74
# 2025-06-11 09:00:00    5505.446667           5475.25    30.20      30.20
# 2025-06-11 10:00:00    6018.292500           6019.82    -1.53       1.53
# 2025-06-11 11:00:00    6196.760833           6582.18  -385.42     385.42
# 2025-06-11 12:00:00    6635.377500           6743.67  -108.29     108.29
# 2025-06-11 13:00:00    6817.769167           6857.22   -39.45      39.45
# 2025-06-11 14:00:00    7320.934833           7205.62   115.31     115.31
# 2025-06-11 15:00:00    7443.936000           7395.09    48.85      48.85
# 2025-06-11 16:00:00    7440.712167           7254.57   186.14     186.14
# 2025-06-11 17:00:00    7180.945833           7015.48   165.46     165.46
# 2025-06-11 18:00:00    6714.210000           6716.59    -2.38       2.38
# 2025-06-11 19:00:00    6624.200833           6640.52   -16.32      16.32
# 2025-06-11 20:00:00    7048.245000           6736.19   312.06     312.06
# 2025-06-11 21:00:00    7423.072833           6797.13   625.94     625.94
# 2025-06-11 22:00:00    7443.936000           6907.96   535.97     535.97
# 2025-06-11 23:00:00    7443.936000           7036.97   406.97     406.97
# 2025-06-12 00:00:00    7443.936000           6708.23   735.71     735.71
# 2025-06-12 01:00:00    7437.372500           6475.66   961.71     961.71
# 2025-06-12 02:00:00    7195.650000           6281.67   913.98     913.98
# 2025-06-12 03:00:00    6878.058333           5975.85   902.21     902.21
# 2025-06-12 04:00:00    6552.440833           5719.96   832.48     832.48
# 2025-06-12 05:00:00    6195.580833           5418.54   777.04     777.04
# 2025-06-12 06:00:00    5861.530833           5256.66   604.87     604.87
# 2025-06-12 07:00:00    5752.405833           5331.57   420.83     420.83
# 2025-06-12 08:00:00    5825.428333           5552.94   272.49     272.49
# 2025-06-12 09:00:00    6332.466667           5954.41   378.06     378.06
# 2025-06-12 10:00:00    6977.677500           6288.81   688.86     688.86
# 2025-06-12 11:00:00    7360.406167           6460.44   899.96     899.96
# 2025-06-12 12:00:00    7443.936000           6643.05   800.89     800.89
# 2025-06-12 13:00:00    7443.936000           6717.61   726.32     726.32
# 2025-06-12 14:00:00    7443.936000           7121.51   322.43     322.43
# 2025-06-12 15:00:00    7443.936000           7285.73   158.21     158.21
# 2025-06-12 16:00:00    7443.936000           7191.06   252.88     252.88
# 2025-06-12 17:00:00    7413.636500           7058.72   354.92     354.92
# 2025-06-12 18:00:00    7073.659167           6705.44   368.22     368.22
# 2025-06-12 19:00:00    6997.954167           6593.50   404.46     404.46
# 2025-06-12 20:00:00    7300.978000           6695.32   605.65     605.65
# 2025-06-12 21:00:00    7443.936000           6803.00   640.94     640.94
# 2025-06-12 22:00:00    7443.936000           6986.40   457.53     457.53
# 2025-06-12 23:00:00    7443.936000           7093.92   350.01     350.01
# 2025-06-13 00:00:00    7443.936000           6906.23   537.70     537.70
# 2025-06-13 01:00:00    7443.936000           6714.21   729.73     729.73
# 2025-06-13 02:00:00    7361.444000           6438.09   923.36     923.36
# 2025-06-13 03:00:00    7014.515833           6045.29   969.22     969.22
# 2025-06-13 04:00:00    6550.389167           5705.61   844.78     844.78
# 2025-06-13 05:00:00    6242.096667           5565.72   676.38     676.38
# 2025-06-13 06:00:00    5854.880833           5464.71   390.17     390.17
# 2025-06-13 07:00:00    5827.320000           5475.21   352.11     352.11
# 2025-06-13 08:00:00    5914.902500           5675.88   239.03     239.03
# 2025-06-13 09:00:00    6426.343333           6077.96   348.38     348.38
# 2025-06-13 10:00:00    7049.470833           6379.90   669.57     669.57
# 2025-06-13 11:00:00    7403.247667           6513.55   889.70     889.70
# 2025-06-13 12:00:00    7443.936000           6669.77   774.17     774.17
# 2025-06-13 13:00:00    7443.936000           6718.31   725.62     725.62
# 2025-06-13 14:00:00    7443.936000           7080.29   363.64     363.64
# 2025-06-13 15:00:00    7443.936000           7187.19   256.75     256.75
# 2025-06-13 16:00:00    7443.936000           7147.27   296.66     296.66
# 2025-06-13 17:00:00    7375.800167           6830.71   545.09     545.09
# 2025-06-13 18:00:00    6863.485000           6299.99   563.50     563.50
# 2025-06-13 19:00:00    6617.412500           6280.94   336.47     336.47
# 2025-06-13 20:00:00    6750.769167           6394.51   356.26     356.26
# 2025-06-13 21:00:00    7125.378333           6465.42   659.96     659.96
# 2025-06-13 22:00:00    7443.936000           6794.95   648.99     648.99
# 2025-06-13 23:00:00    7443.936000           6990.03   453.90     453.90
# 2025-06-14 00:00:00    7443.936000           6706.98   736.96     736.96
# 2025-06-14 01:00:00    7241.521333           6445.93   795.59     795.59
# 2025-06-14 02:00:00    6881.684167           6100.81   780.87     780.87
# 2025-06-14 03:00:00    6571.589167           5833.69   737.90     737.90
# 2025-06-14 04:00:00    6254.878333           5506.66   748.22     748.22
# 2025-06-14 05:00:00    5908.872500           5206.40   702.48     702.48
# 2025-06-14 06:00:00    5608.437500           4967.23   641.20     641.20
# 2025-06-14 07:00:00    5418.940000           4876.85   542.09     542.09
# 2025-06-14 08:00:00    5366.407500           4981.77   384.63     384.63
# 2025-06-14 09:00:00    5568.706667           5239.18   329.53     329.53
# 2025-06-14 10:00:00    6166.421667           5518.78   647.64     647.64
# 2025-06-14 11:00:00    6682.537500           5741.70   940.84     940.84
# 2025-06-14 12:00:00    7100.973333           5965.49  1135.48    1135.48
# 2025-06-14 13:00:00    7310.759000           6110.20  1200.56    1200.56
# 2025-06-14 14:00:00    7443.936000           6625.89   818.05     818.05
# 2025-06-14 15:00:00    7443.936000           6781.77   662.16     662.16
# 2025-06-14 16:00:00    7443.936000           6664.79   779.14     779.14
# 2025-06-14 17:00:00    7226.491667           6456.09   770.40     770.40
# 2025-06-14 18:00:00    6793.777500           6093.22   700.56     700.56
# 2025-06-14 19:00:00    6733.626667           5927.63   805.99     805.99
# 2025-06-14 20:00:00    7032.017500           6064.17   967.85     967.85
# 2025-06-14 21:00:00    7381.472167           6308.32  1073.15    1073.15
# 2025-06-14 22:00:00    7443.936000           6541.87   902.07     902.07
# 2025-06-14 23:00:00    7443.936000           6768.30   675.63     675.63
# 2025-06-15 00:00:00    7443.936000           6538.99   904.95     904.95
# 2025-06-15 01:00:00    7418.350833           6331.27  1087.08    1087.08
# 2025-06-15 02:00:00    7124.887500           6099.40  1025.49    1025.49
# 2025-06-15 03:00:00    6366.554167           5735.32   631.24     631.24
# 2025-06-15 04:00:00    5237.449167           5308.16   -70.71      70.71
# 2025-06-15 05:00:00    5097.454167           4943.85   153.60     153.60
# 2025-06-15 06:00:00    5150.335000           4772.97   377.37     377.37
# 2025-06-15 07:00:00    5042.436667           4502.84   539.59     539.59
# 2025-06-15 08:00:00    5036.017500           4515.24   520.77     520.77
# 2025-06-15 09:00:00    5030.975000           4773.79   257.18     257.18
# 2025-06-15 10:00:00    5276.300833           5041.80   234.50     234.50
# 2025-06-15 11:00:00    5602.655000           5162.61   440.04     440.04
# 2025-06-15 12:00:00    5911.700000           5606.41   305.29     305.29
# 2025-06-15 13:00:00    5957.438333           5930.49    26.95      26.95
# 2025-06-15 14:00:00    6179.273333           6234.34   -55.06      55.06
# 2025-06-15 15:00:00    6329.734167           6245.61    84.12      84.12
# 2025-06-15 16:00:00    6163.376667           6277.80  -114.43     114.43
# 2025-06-15 17:00:00    5840.950833           6024.03  -183.08     183.08
# 2025-06-15 18:00:00    5589.016667           5523.30    65.71      65.71
# 2025-06-15 19:00:00    5609.033333           5523.12    85.91      85.91
# 2025-06-15 20:00:00    5966.228333           5734.14   232.09     232.09
# 2025-06-15 21:00:00    6390.601667           5906.91   483.69     483.69
# 2025-06-15 22:00:00    6891.207500           6194.44   696.77     696.77
# 2025-06-15 23:00:00    7183.272000           6476.50   706.78     706.78
# 2025-06-16 00:00:00    7017.050000           6487.47   529.58     529.58
# 2025-06-16 01:00:00    6672.590833           6238.81   433.78     433.78
# 2025-06-16 02:00:00    6341.571667           5956.61   384.96     384.96
# 2025-06-16 03:00:00    6044.535000           5691.18   353.36     353.36
# 2025-06-16 04:00:00    5784.418333           5282.54   501.88     501.88
# 2025-06-16 05:00:00    5536.685833           4523.29  1013.40    1013.40
# 2025-06-16 06:00:00    5323.271667           4406.27   917.00     917.00
# 2025-06-16 07:00:00    5221.776667           4524.12   697.66     697.66
# 2025-06-16 08:00:00    5327.935833           4620.33   707.61     707.61
# 2025-06-16 09:00:00    5719.628333           4742.47   977.16     977.16
# 2025-06-16 10:00:00    6099.262500           5295.20   804.06     804.06
# 2025-06-16 11:00:00    6295.942500           5638.67   657.27     657.27
# 2025-06-16 12:00:00    6368.875000           5706.63   662.24     662.24
# 2025-06-16 13:00:00    6259.538333           5759.91   499.63     499.63
# 2025-06-16 14:00:00    6508.550833           5940.37   568.18     568.18
# 2025-06-16 15:00:00    6699.860000           5947.66   752.20     752.20
# 2025-06-16 16:00:00    6652.330000           5955.70   696.63     696.63
# 2025-06-16 17:00:00    6394.800833           5902.58   492.22     492.22
# 2025-06-16 18:00:00    6044.991667           5703.28   341.72     341.72
# 2025-06-16 19:00:00    5989.514167           5653.46   336.05     336.05
# 2025-06-16 20:00:00    6106.913333           5773.41   333.51     333.51
# 2025-06-16 21:00:00    6401.770000           6010.42   391.35     391.35
# 2025-06-16 22:00:00    6870.872500           6213.55   657.32     657.32
# 2025-06-16 23:00:00    7069.971818           6197.60   872.37     872.37
# 2025-06-17 00:00:00    6814.917500           6091.40   723.52     723.52
# 2025-06-17 01:00:00    6443.062500           5882.99   560.08     560.08
# 2025-06-17 02:00:00    6093.965833           5664.79   429.17     429.17
# 2025-06-17 03:00:00    5761.155000           5290.05   471.10     471.10
# 2025-06-17 04:00:00    5503.758333           4956.73   547.03     547.03
# 2025-06-17 05:00:00    5241.718333           4672.39   569.33     569.33
# 2025-06-17 06:00:00    5041.374167           4739.48   301.90     301.90
# 2025-06-17 07:00:00    4986.152500           4658.78   327.37     327.37
# 2025-06-17 08:00:00    5134.895000           4783.18   351.72     351.72
# 2025-06-17 09:00:00    5591.249167           5142.60   448.65     448.65
# 2025-06-17 10:00:00    6086.580000           5674.21   412.37     412.37
# 2025-06-17 11:00:00    6423.510833           5974.28   449.23     449.23
# 2025-06-17 12:00:00    6688.240833           6196.03   492.21     492.21
# 2025-06-17 13:00:00    6826.278333           6210.01   616.27     616.27
# 2025-06-17 14:00:00    6841.047500           6505.32   335.73     335.73
# 2025-06-17 15:00:00    5980.705000           6429.13  -448.43     448.43
# 2025-06-17 16:00:00    5687.280000           6253.55  -566.27     566.27
# 2025-06-17 17:00:00    5785.130833           5980.06  -194.93     194.93
# 2025-06-17 18:00:00    5620.379167           5887.31  -266.93     266.93
# 2025-06-17 19:00:00    5341.593333           5830.91  -489.31     489.31
# 2025-06-17 20:00:00    5316.880833           5990.83  -673.95     673.95
# 2025-06-17 21:00:00    5455.984167           5944.77  -488.79     488.79
# 2025-06-17 22:00:00    5771.300000           5990.83  -219.53     219.53
# 2025-06-17 23:00:00    5920.663000           5984.38   -63.72      63.72
# 2025-06-18 00:00:00    5709.320000           5780.69   -71.37      71.37
# 2025-06-18 01:00:00    5425.346667           5462.96   -37.62      37.62
# 2025-06-18 02:00:00    5143.718333           5233.26   -89.54      89.54
# 2025-06-18 03:00:00    4885.903333           4925.07   -39.17      39.17
# 2025-06-18 04:00:00    4678.901667           4671.04     7.87       7.87
# 2025-06-18 05:00:00    4495.299167           4543.97   -48.68      48.68
# 2025-06-18 06:00:00    4410.611667           4612.72  -202.11     202.11
# 2025-06-18 07:00:00    4446.057500           4665.98  -219.92     219.92
# 2025-06-18 08:00:00    4599.752500           4745.02  -145.27     145.27
# 2025-06-18 09:00:00    5031.588333           5075.03   -43.44      43.44
# 2025-06-18 10:00:00    5589.507500           5555.24    34.26      34.26
# 2025-06-18 11:00:00    5802.755833           5858.07   -55.31      55.31
# 2025-06-18 12:00:00    5879.815833           5965.15   -85.33      85.33
# 2025-06-18 13:00:00    5839.722500           5986.53  -146.80     146.80
# 2025-06-18 14:00:00    6265.897500           6161.74   104.16     104.16
# 2025-06-18 15:00:00    6416.988333           6206.66   210.33     210.33
# 2025-06-18 16:00:00    6350.715833           6146.06   204.65     204.65
# 2025-06-18 17:00:00    6193.524167           6019.78   173.75     173.75
# 2025-06-18 18:00:00    5874.973333           5940.35   -65.38      65.38
# 2025-06-18 19:00:00    5849.894167           5844.62     5.28       5.28
# 2025-06-18 20:00:00    5959.606667           5890.39    69.22      69.22
# 2025-06-18 21:00:00    6155.865833           5910.39   245.48     245.48
# 2025-06-18 22:00:00    6394.386667           6243.21   151.18     151.18
# 2025-06-18 23:00:00    6447.806364           6413.54    34.26      34.26
# 2025-06-19 00:00:00    6155.713333           6282.13  -126.41     126.41
# 2025-06-19 01:00:00    5787.525833           5911.77  -124.24     124.24
# 2025-06-19 02:00:00    5452.414167           5677.42  -225.01     225.01
# 2025-06-19 03:00:00    5199.830000           5393.32  -193.49     193.49
# 2025-06-19 04:00:00    4971.245000           5287.02  -315.77     315.77
# 2025-06-19 05:00:00    4733.727500           4984.62  -250.89     250.89
# 2025-06-19 06:00:00    4613.429167           4798.33  -184.90     184.90
# 2025-06-19 07:00:00    4652.838333           4728.50   -75.67      75.67
# 2025-06-19 08:00:00    4788.458333           4887.16   -98.71      98.71
# 2025-06-19 09:00:00    5255.021667           5286.91   -31.89      31.89
# 2025-06-19 10:00:00    5789.670833           5625.82   163.86     163.86
# 2025-06-19 11:00:00    6037.259167           5751.16   286.10     286.10
# 2025-06-19 12:00:00    6195.217500           5898.22   297.00     297.00
# 2025-06-19 13:00:00    6240.745833           5872.12   368.63     368.63
# 2025-06-19 14:00:00    6604.080000           6057.53   546.55     546.55
# 2025-06-19 15:00:00    6742.772500           6136.13   606.64     606.64
# 2025-06-19 16:00:00    6596.907500           6086.83   510.08     510.08
# 2025-06-19 17:00:00    6410.918333           5933.22   477.70     477.70
# 2025-06-19 18:00:00    6062.185000           5736.37   325.82     325.82
# 2025-06-19 19:00:00    5943.198333           5706.84   236.36     236.36
# 2025-06-19 20:00:00    6027.635000           5791.07   236.56     236.56
# 2025-06-19 21:00:00    6310.655833           5928.29   382.37     382.37
# 2025-06-19 22:00:00    6724.406667           6252.17   472.24     472.24
# 2025-06-19 23:00:00    6873.576667           6306.54   567.04     567.04
# 2025-06-20 00:00:00    6535.493333           6203.56   331.93     331.93
# 2025-06-20 01:00:00    6074.270000           5840.92   233.35     233.35
# 2025-06-20 02:00:00    5651.097500           5611.15    39.95      39.95
# 2025-06-20 03:00:00    5328.809167           5187.51   141.30     141.30
# 2025-06-20 04:00:00    5055.667500           4911.26   144.40     144.40
# 2025-06-20 05:00:00    4829.610833           4945.80  -116.19     116.19
# 2025-06-20 06:00:00    4706.450000           4991.18  -284.73     284.73
# 2025-06-20 07:00:00    4720.841667           5011.30  -290.46     290.46
# 2025-06-20 08:00:00    4822.210833           5145.75  -323.54     323.54
# 2025-06-20 09:00:00    5322.168333           5394.88   -72.71      72.71
# 2025-06-20 10:00:00    5836.622500           5720.95   115.67     115.67
# 2025-06-20 11:00:00    6008.637500           5937.19    71.45      71.45
# 2025-06-20 12:00:00    6196.106667           5939.04   257.07     257.07
# 2025-06-20 13:00:00    6177.919167           5807.19   370.73     370.73
# 2025-06-20 14:00:00    6400.134167           5940.04   460.09     460.09
# 2025-06-20 15:00:00    6627.086667           6029.96   597.13     597.13
# 2025-06-20 16:00:00    6501.934167           5978.25   523.68     523.68
# 2025-06-20 17:00:00    6272.935833           5898.51   374.42     374.42
# 2025-06-20 18:00:00    5944.312500           5771.83   172.49     172.49
# 2025-06-20 19:00:00    5624.195833           5724.30  -100.10     100.10
# 2025-06-20 20:00:00    5866.979167           5742.35   124.63     124.63
# 2025-06-20 21:00:00    6166.268333           5846.17   320.10     320.10
# 2025-06-20 22:00:00    6515.604167           6090.33   425.27     425.27
# 2025-06-20 23:00:00    6645.253333           6209.09   436.16     436.16
# 2025-06-21 00:00:00    6339.271667           5947.31   391.96     391.96
# 2025-06-21 01:00:00    5956.987500           5649.69   307.30     307.30
# 2025-06-21 02:00:00    5620.139167           5345.47   274.67     274.67
# 2025-06-21 03:00:00    5346.313333           4940.33   405.98     405.98
# 2025-06-21 04:00:00    5119.339167           4776.65   342.69     342.69
# 2025-06-21 05:00:00    4844.775833           4775.65    69.13      69.13
# 2025-06-21 06:00:00    4701.684167           4730.83   -29.15      29.15
# 2025-06-21 07:00:00    4714.435000           4618.82    95.62      95.62
# 2025-06-21 08:00:00    4758.426667           4654.00   104.42     104.42
# 2025-06-21 09:00:00    5079.426667           4958.56   120.86     120.86
# 2025-06-21 10:00:00    5619.262500           5507.63   111.64     111.64
# 2025-06-21 11:00:00    5956.491667           5669.26   287.24     287.24
# 2025-06-21 12:00:00    6204.290000           5831.18   373.11     373.11
# 2025-06-21 13:00:00    6289.849167           5899.77   390.08     390.08
# 2025-06-21 14:00:00    6676.360833           6250.06   426.30     426.30
# 2025-06-21 15:00:00    6796.709167           6237.69   559.02     559.02
# 2025-06-21 16:00:00    6512.000833           6106.99   405.01     405.01
# 2025-06-21 17:00:00    6112.880833           5751.69   361.19     361.19
# 2025-06-21 18:00:00    5887.148333           5583.57   303.57     303.57
# 2025-06-21 19:00:00    5913.658333           5639.41   274.25     274.25
# 2025-06-21 20:00:00    6186.065000           5855.08   330.99     330.99
# 2025-06-21 21:00:00    6444.660000           6039.15   405.51     405.51
# 2025-06-21 22:00:00    6826.654167           6320.82   505.83     505.83
# 2025-06-21 23:00:00    6919.411667           6452.51   466.90     466.90
# 2025-06-22 00:00:00    6610.431667           6189.54   420.90     420.90
# 2025-06-22 01:00:00    6286.450833           5871.30   415.15     415.15
# 2025-06-22 02:00:00    5931.765833           5605.73   326.04     326.04
# 2025-06-22 03:00:00    5636.834167           5287.12   349.71     349.71
# 2025-06-22 04:00:00    5343.710000           5031.76   311.95     311.95
# 2025-06-22 05:00:00    5092.120000           4792.95   299.17     299.17
# 2025-06-22 06:00:00    4897.118333           4583.23   313.89     313.89
# 2025-06-22 07:00:00    4788.023333           4487.78   300.24     300.24
# 2025-06-22 08:00:00    4738.865833           4517.89   220.98     220.98
# 2025-06-22 09:00:00    4950.253333           4712.43   237.83     237.83
# 2025-06-22 10:00:00    5323.322500           5079.56   243.76     243.76
# 2025-06-22 11:00:00    5610.545000           5260.10   350.45     350.45
# 2025-06-22 12:00:00    5830.745833           5203.37   627.37     627.37
# 2025-06-22 13:00:00    5891.628333           5201.81   689.82     689.82
# 2025-06-22 14:00:00    6252.517500           5533.67   718.85     718.85
# 2025-06-22 15:00:00    6420.141667           5647.69   772.46     772.46
# 2025-06-22 16:00:00    6198.646667           5667.18   531.47     531.47
# 2025-06-22 17:00:00    5907.083333           5504.84   402.25     402.25
# 2025-06-22 18:00:00    5600.569167           5253.38   347.19     347.19
# 2025-06-22 19:00:00    5676.602500           5294.27   382.33     382.33
# 2025-06-22 20:00:00    5987.625833           5546.43   441.19     441.19
# 2025-06-22 21:00:00    6266.923333           5842.62   424.30     424.30
# 2025-06-22 22:00:00    6652.833333           6204.64   448.19     448.19
# 2025-06-22 23:00:00    6799.963333           6365.13   434.83     434.83
# 2025-06-23 00:00:00    6545.230000           6264.61   280.62     280.62
# 2025-06-23 01:00:00    6177.413333           5989.00   188.41     188.41
# 2025-06-23 02:00:00    5848.475000           5670.70   177.77     177.77
# 2025-06-23 03:00:00    5537.015833           5263.88   273.13     273.13
# 2025-06-23 04:00:00    5286.132500           5132.45   153.68     153.68
# 2025-06-23 05:00:00    5052.745833           5065.88   -13.13      13.13
# 2025-06-23 06:00:00    4923.440833           5076.75  -153.31     153.31
# 2025-06-23 07:00:00    4945.132500           5031.63   -86.49      86.49
# 2025-06-23 08:00:00    5132.685833           5120.25    12.44      12.44
# 2025-06-23 09:00:00    5656.000833           5364.86   291.14     291.14
# 2025-06-23 10:00:00    6220.430833           5897.29   323.14     323.14
# 2025-06-23 11:00:00    6519.934167           6201.68   318.26     318.26
# 2025-06-23 12:00:00    6762.792500           6361.92   400.87     400.87
# 2025-06-23 13:00:00    6823.526667           6410.51   413.02     413.02
# 2025-06-23 14:00:00    7269.691667           6590.58   679.11     679.11
# 2025-06-23 15:00:00    7421.163000           6667.56   753.60     753.60
# 2025-06-23 16:00:00    7204.613333           6508.86   695.75     695.75
# 2025-06-23 17:00:00    6781.490833           6289.16   492.33     492.33
# 2025-06-23 18:00:00    6269.156667           6016.99   252.16     252.16
# 2025-06-23 19:00:00    5962.303333           5889.35    72.95      72.95
# 2025-06-23 20:00:00    5976.563333           6162.54  -185.98     185.98
# 2025-06-23 21:00:00    6235.234167           6388.76  -153.52     153.52
# 2025-06-23 22:00:00    6705.915833           6655.14    50.77      50.77
# 2025-06-23 23:00:00    6879.277500           6675.45   203.82     203.82
# 2025-06-24 00:00:00    6590.937500           6422.84   168.09     168.09
# 2025-06-24 01:00:00    6219.537500           6106.23   113.31     113.31
# 2025-06-24 02:00:00    5890.404167           5804.74    85.66      85.66
# 2025-06-24 03:00:00    5602.498333           5418.08   184.42     184.42
# 2025-06-24 04:00:00    5321.775833           5186.96   134.82     134.82
# 2025-06-24 05:00:00    5100.744167           4965.49   135.25     135.25
# 2025-06-24 06:00:00    4959.608333           4809.36   150.25     150.25
# 2025-06-24 07:00:00    4952.492500           4792.71   159.79     159.79
# 2025-06-24 08:00:00    5097.242500           5041.24    56.00      56.00
# 2025-06-24 09:00:00    5565.065000           5371.98   193.08     193.08
# 2025-06-24 10:00:00    6086.574167           5852.65   233.92     233.92
# 2025-06-24 11:00:00    6402.042500           6223.37   178.68     178.68
# 2025-06-24 12:00:00    6619.008333           6546.48    72.53      72.53
# 2025-06-24 13:00:00    6686.740000           6573.06   113.68     113.68
# 2025-06-24 14:00:00    6968.387500           6869.96    98.43      98.43
# 2025-06-24 15:00:00    6952.428333           6761.89   190.54     190.54
# 2025-06-24 16:00:00    6684.055833           6721.13   -37.08      37.08
# 2025-06-24 17:00:00    6512.243333           6324.89   187.36     187.36
# 2025-06-24 18:00:00    6175.030833           5961.27   213.76     213.76
# 2025-06-24 19:00:00    6137.152500           5992.88   144.27     144.27
# 2025-06-24 20:00:00    6306.969167           6255.44    51.53      51.53
# 2025-06-24 21:00:00    6561.222500           6423.42   137.81     137.81
# 2025-06-24 22:00:00    6939.159167           6802.11   137.05     137.05
# 2025-06-24 23:00:00    7058.703000           6926.89   131.82     131.82
# 2025-06-25 00:00:00    6726.734167           6717.99     8.74       8.74
# 2025-06-25 01:00:00    6337.179167           6360.41   -23.23      23.23
# 2025-06-25 02:00:00    6015.970000           6080.87   -64.90      64.90
# 2025-06-25 03:00:00    5732.853333           5817.29   -84.44      84.44
# 2025-06-25 04:00:00    5492.600833           5352.70   139.90     139.90
# 2025-06-25 05:00:00    5286.078333           5099.84   186.24     186.24
# 2025-06-25 06:00:00    5162.299167           5034.43   127.87     127.87
# 2025-06-25 07:00:00    5154.729167           5046.00   108.73     108.73
# 2025-06-25 08:00:00    5282.337500           5098.97   183.37     183.37
# 2025-06-25 09:00:00    5709.763333           5280.58   429.18     429.18
# 2025-06-25 10:00:00    6211.397500           5639.86   571.53     571.53
# 2025-06-25 11:00:00    6469.721667           5877.36   592.36     592.36
# 2025-06-25 12:00:00    6604.755000           5959.36   645.39     645.39
# 2025-06-25 13:00:00    6544.682500           5875.16   669.52     669.52
# 2025-06-25 14:00:00    6925.796667           6240.08   685.71     685.71
# 2025-06-25 15:00:00    7017.901667           6394.50   623.40     623.40
# 2025-06-25 16:00:00    6808.376667           6382.20   426.18     426.18
# 2025-06-25 17:00:00    6599.953333           6146.49   453.46     453.46
# 2025-06-25 18:00:00    6295.176667           5941.28   353.90     353.90
# 2025-06-25 19:00:00    6248.241667           5823.04   425.20     425.20
# 2025-06-25 20:00:00    6376.143333           5883.01   493.14     493.14
# 2025-06-25 21:00:00    6548.332500           6072.17   476.17     476.17
# 2025-06-25 22:00:00    6862.115000           6386.09   476.02     476.02
# 2025-06-25 23:00:00    6985.435556           6616.03   369.40     369.40
# 2025-06-26 00:00:00    6628.393333           6266.27   362.12     362.12
# 2025-06-26 01:00:00    6243.325000           6058.72   184.60     184.60
# 2025-06-26 02:00:00    5913.485833           5589.29   324.20     324.20
# 2025-06-26 03:00:00    5618.103333           5224.73   393.37     393.37
# 2025-06-26 04:00:00    5369.710833           5072.15   297.56     297.56
# 2025-06-26 05:00:00    5150.445000           5141.23     9.21       9.21
# 2025-06-26 06:00:00    5002.678333           5119.25  -116.57     116.57
# 2025-06-26 07:00:00    4996.470000           5133.52  -137.05     137.05
# 2025-06-26 08:00:00    5088.985833           5268.25  -179.26     179.26
# 2025-06-26 09:00:00    5597.330833           5518.00    79.33      79.33
# 2025-06-26 10:00:00    6210.059167           5970.39   239.67     239.67
# 2025-06-26 11:00:00    6567.052500           6153.12   413.93     413.93
# 2025-06-26 12:00:00    6826.540833           6343.20   483.34     483.34
# 2025-06-26 13:00:00    6906.114167           6425.67   480.45     480.45
# 2025-06-26 14:00:00    7256.352500           6707.29   549.06     549.06
# 2025-06-26 15:00:00    7378.705000           6666.46   712.24     712.24
# 2025-06-26 16:00:00    7204.080833           6479.96   724.12     724.12
# 2025-06-26 17:00:00    6916.464167           6266.52   649.94     649.94
# 2025-06-26 18:00:00    6483.189167           6037.62   445.57     445.57
# 2025-06-26 19:00:00    6375.083333           6008.03   367.05     367.05
# 2025-06-26 20:00:00    6541.566667           6148.21   393.36     393.36
# 2025-06-26 21:00:00    6816.450000           6258.88   557.57     557.57
# 2025-06-26 22:00:00    7267.064167           6582.39   684.67     684.67
# 2025-06-26 23:00:00    7380.972167           6643.74   737.23     737.23
# 2025-06-27 00:00:00    7041.066667           6379.16   661.90     661.90
# 2025-06-27 01:00:00    6634.701667           6068.66   566.04     566.04
# 2025-06-27 02:00:00    6255.272500           5850.27   405.00     405.00
# 2025-06-27 03:00:00    5926.683333           5453.04   473.64     473.64
# 2025-06-27 04:00:00    5653.036667           5276.06   376.97     376.97
# 2025-06-27 05:00:00    5380.835000           5133.45   247.39     247.39
# 2025-06-27 06:00:00    5195.476667           5078.67   116.81     116.81
# 2025-06-27 07:00:00    5199.610000           5014.58   185.03     185.03
# 2025-06-27 08:00:00    5319.553333           5015.12   304.43     304.43
# 2025-06-27 09:00:00    5843.138333           5306.01   537.13     537.13
# 2025-06-27 10:00:00    6354.398333           5650.31   704.09     704.09
# 2025-06-27 11:00:00    6671.686667           5925.04   746.64     746.64
# 2025-06-27 12:00:00    6958.728333           6120.76   837.96     837.96
# 2025-06-27 13:00:00    6982.008333           6390.39   591.62     591.62
# 2025-06-27 14:00:00    7364.727000           6470.79   893.93     893.93
# 2025-06-27 15:00:00    7443.936000           6363.42  1080.52    1080.52
# 2025-06-27 16:00:00    7374.966500           6270.99  1103.98    1103.98
# 2025-06-27 17:00:00    7000.464167           6133.84   866.63     866.63
# 2025-06-27 18:00:00    6600.595000           5984.51   616.08     616.08
# 2025-06-27 19:00:00    6453.698333           5865.47   588.23     588.23
# 2025-06-27 20:00:00    6621.233333           5992.70   628.53     628.53
# 2025-06-27 21:00:00    6954.114167           6078.63   875.48     875.48
# 2025-06-27 22:00:00    7373.706667           6360.40  1013.30    1013.30
# 2025-06-27 23:00:00    7443.936000           6554.58   889.35     889.35
# 2025-06-28 00:00:00    7263.248833           6166.56  1096.69    1096.69
# 2025-06-28 01:00:00    6870.139167           5710.17  1159.97    1159.97
# 2025-06-28 02:00:00    6452.725833           5256.19  1196.54    1196.54
# 2025-06-28 03:00:00    6139.911667           4822.43  1317.48    1317.48
# 2025-06-28 04:00:00    5843.964167           4545.16  1298.80    1298.80
# 2025-06-28 05:00:00    5564.558333           4719.39   845.17     845.17
# 2025-06-28 06:00:00    5360.768333           4755.65   605.12     605.12
# 2025-06-28 07:00:00    5262.835000           4672.27   590.57     590.57
# 2025-06-28 08:00:00    5229.273333           4756.82   472.45     472.45
# 2025-06-28 09:00:00    5552.843333           5003.97   548.88     548.88
# 2025-06-28 10:00:00    6121.090000           5391.45   729.64     729.64
# 2025-06-28 11:00:00    6463.380000           5741.60   721.78     721.78
# 2025-06-28 12:00:00    6774.139167           5838.47   935.67     935.67
# 2025-06-28 13:00:00    6835.678333           5904.32   931.36     931.36
# 2025-06-28 14:00:00    7030.866667           6300.70   730.17     730.17
# 2025-06-28 15:00:00    6657.924167           6370.59   287.33     287.33
# 2025-06-28 16:00:00    6071.902500           6238.71  -166.81     166.81
# 2025-06-28 17:00:00    5873.467500           5722.08   151.38     151.38
# 2025-06-28 18:00:00    5643.923333           5580.82    63.11      63.11
# 2025-06-28 19:00:00    5714.234167           5629.51    84.72      84.72
# 2025-06-28 20:00:00    5886.333333           5806.09    80.24      80.24
# 2025-06-28 21:00:00    6077.290833           6025.68    51.61      51.61
# 2025-06-28 22:00:00    6412.950000           6328.85    84.10      84.10
# 2025-06-28 23:00:00    6555.372727           6420.41   134.96     134.96
# 2025-06-29 00:00:00    6323.930833           5843.75   480.18     480.18
# 2025-06-29 01:00:00    5981.348333           5437.22   544.12     544.12
# ...
# 2026-03-23 21:00:00    3284.280833           2996.99   287.29     287.29
# 2026-03-23 22:00:00    3090.594167           2776.66   313.93     313.93
# 2026-03-23 23:00:00    2897.625000           2662.02   235.60     235.60
# 2026-03-24 00:00:00    2715.595000           2424.04   291.55     291.55
# 2026-03-24 01:00:00    2616.177500           2272.03   344.14     344.14
# 2026-03-24 02:00:00    2508.695000           2142.46   366.23     366.23
# 2026-03-24 03:00:00    2454.726667           2113.92   340.81     340.81
# 2026-03-24 04:00:00    2498.997500           2219.76   279.24     279.24
# 2026-03-24 05:00:00    2739.420000           2548.25   191.17     191.17
# 2026-03-24 06:00:00    3192.220833           3050.80   141.42     141.42
# 2026-03-24 07:00:00    3619.986667           3471.85   148.13     148.13
# 2026-03-24 08:00:00    3725.615833           3513.50   212.11     212.11
# 2026-03-24 09:00:00    3824.401667           3611.46   212.94     212.94
# 2026-03-24 10:00:00    3932.690833           3728.66   204.03     204.03
# 2026-03-24 11:00:00    3901.415833           3723.02   178.39     178.39
# 2026-03-24 12:00:00    3888.869167           3677.13   211.74     211.74
# 2026-03-24 13:00:00    3670.770833           3437.65   233.12     233.12
# 2026-03-24 14:00:00    3707.945833           3449.78   258.17     258.17
# 2026-03-24 15:00:00    3729.891667           3483.46   246.43     246.43
# 2026-03-24 16:00:00    3748.045833           3429.18   318.86     318.86
# 2026-03-24 17:00:00    3800.726667           3530.07   270.66     270.66
# 2026-03-24 18:00:00    3878.461667           3585.04   293.42     293.42
# 2026-03-24 19:00:00    3885.535000           3523.51   362.02     362.02
# 2026-03-24 20:00:00    3657.389167           3258.36   399.03     399.03
# 2026-03-24 21:00:00    3420.736667           3056.45   364.29     364.29
# 2026-03-24 22:00:00    3239.252500           2812.84   426.41     426.41
# 2026-03-24 23:00:00    3066.616000           2673.24   393.38     393.38
# 2026-03-25 00:00:00    2867.335000           2441.53   425.81     425.81
# 2026-03-25 01:00:00    2711.642500           2248.85   462.79     462.79
# 2026-03-25 02:00:00    2622.828333           2173.83   449.00     449.00
# 2026-03-25 03:00:00    2596.805000           2109.54   487.26     487.26
# 2026-03-25 04:00:00    2639.802500           2231.11   408.70     408.70
# 2026-03-25 05:00:00    2846.691667           2574.36   272.33     272.33
# 2026-03-25 06:00:00    3292.644167           3071.35   221.30     221.30
# 2026-03-25 07:00:00    3678.969167           3484.23   194.74     194.74
# 2026-03-25 08:00:00    3767.020000           3527.41   239.61     239.61
# 2026-03-25 09:00:00    3897.711667           3613.41   284.30     284.30
# 2026-03-25 10:00:00    4034.714167           3780.55   254.16     254.16
# 2026-03-25 11:00:00    4028.875000           3805.99   222.88     222.88
# 2026-03-25 12:00:00    3974.399167           3813.17   161.23     161.23
# 2026-03-25 13:00:00    3654.925833           3582.36    72.57      72.57
# 2026-03-25 14:00:00    3735.900833           3615.39   120.51     120.51
# 2026-03-25 15:00:00    3805.206667           3659.03   146.18     146.18
# 2026-03-25 16:00:00    3861.310000           3615.82   245.49     245.49
# 2026-03-25 17:00:00    3912.354167           3724.83   187.52     187.52
# 2026-03-25 18:00:00    3993.041667           3728.93   264.11     264.11
# 2026-03-25 19:00:00    3995.672500           3652.30   343.37     343.37
# 2026-03-25 20:00:00    3753.086667           3491.78   261.31     261.31
# 2026-03-25 21:00:00    3521.867500           3281.30   240.57     240.57
# 2026-03-25 22:00:00    3378.047500           3117.13   260.91     260.91
# 2026-03-25 23:00:00    3184.046667           3057.86   126.19     126.19
# 2026-03-26 00:00:00    2985.348333           2759.92   225.43     225.43
# 2026-03-26 01:00:00    2837.133333           2600.70   236.43     236.43
# 2026-03-26 02:00:00    2743.018333           2560.15   182.87     182.87
# 2026-03-26 03:00:00    2719.149167           2465.43   253.72     253.72
# 2026-03-26 04:00:00    2779.469167           2521.61   257.86     257.86
# 2026-03-26 05:00:00    3038.257500           2687.90   350.36     350.36
# 2026-03-26 06:00:00    3464.555833           3048.10   416.45     416.45
# 2026-03-26 07:00:00    3770.490000           3431.29   339.20     339.20
# 2026-03-26 08:00:00    3726.083333           3482.04   244.04     244.04
# 2026-03-26 09:00:00    3763.723333           3694.48    69.24      69.24
# 2026-03-26 10:00:00    3888.910833           3873.18    15.73      15.73
# 2026-03-26 11:00:00    3897.765833           4028.34  -130.57     130.57
# 2026-03-26 12:00:00    3915.904167           4119.68  -203.78     203.78
# 2026-03-26 13:00:00    3741.612500           3853.00  -111.39     111.39
# 2026-03-26 14:00:00    3855.151667           3797.78    57.37      57.37
# 2026-03-26 15:00:00    3890.784167           3786.60   104.19     104.19
# 2026-03-26 16:00:00    3891.663333           3700.62   191.04     191.04
# 2026-03-26 17:00:00    3917.577500           3817.34   100.24     100.24
# 2026-03-26 18:00:00    4013.422500           3858.93   154.50     154.50
# 2026-03-26 19:00:00    4026.127500           3884.45   141.68     141.68
# 2026-03-26 20:00:00    3819.688333           3759.17    60.52      60.52
# 2026-03-26 21:00:00    3635.120833           3568.43    66.69      66.69
# 2026-03-26 22:00:00    3457.781667           3564.63  -106.85     106.85
# 2026-03-26 23:00:00    3287.542727           3514.19  -226.65     226.65
# 2026-03-27 00:00:00    3091.255000           3020.50    70.76      70.76
# 2026-03-27 01:00:00    2947.195833           2697.01   250.18     250.18
# 2026-03-27 02:00:00    2868.809167           2538.30   330.51     330.51
# 2026-03-27 03:00:00    2829.811667           2526.68   303.13     303.13
# 2026-03-27 04:00:00    2892.811667           2554.22   338.59     338.59
# 2026-03-27 05:00:00    3140.291667           2655.46   484.83     484.83
# 2026-03-27 06:00:00    3511.589167           2866.65   644.94     644.94
# 2026-03-27 07:00:00    3746.391667           3250.79   495.60     495.60
# 2026-03-27 08:00:00    3801.291667           3229.85   571.44     571.44
# 2026-03-27 09:00:00    3932.529167           3267.13   665.40     665.40
# 2026-03-27 10:00:00    4161.085000           3491.54   669.55     669.55
# 2026-03-27 11:00:00    4210.900000           3531.75   679.15     679.15
# 2026-03-27 12:00:00    4154.585833           3351.88   802.70     802.70
# 2026-03-27 13:00:00    3930.585000           3080.37   850.21     850.21
# 2026-03-27 14:00:00    4002.720833           3066.85   935.87     935.87
# 2026-03-27 15:00:00    4043.304167           3095.74   947.57     947.57
# 2026-03-27 16:00:00    4068.948333           3062.46  1006.49    1006.49
# 2026-03-27 17:00:00    4126.961667           3148.18   978.78     978.78
# 2026-03-27 18:00:00    4184.585000           3280.67   903.92     903.92
# 2026-03-27 19:00:00    4165.319167           3308.25   857.07     857.07
# 2026-03-27 20:00:00    3950.583333           3191.62   758.97     758.97
# 2026-03-27 21:00:00    3718.645000           3017.47   701.18     701.18
# 2026-03-27 22:00:00    3553.420000           2843.91   709.51     709.51
# 2026-03-27 23:00:00    3418.127000           2759.68   658.45     658.45
# 2026-03-28 00:00:00    3216.114167           2736.68   479.44     479.44
# 2026-03-28 01:00:00    3061.423333           2654.12   407.30     407.30
# 2026-03-28 02:00:00    2972.390000           2591.25   381.14     381.14
# 2026-03-28 03:00:00    2921.009167           2582.27   338.73     338.73
# 2026-03-28 04:00:00    2928.361667           2606.10   322.26     322.26
# 2026-03-28 05:00:00    3072.860000           2715.03   357.83     357.83
# 2026-03-28 06:00:00    3368.107500           2974.53   393.58     393.58
# 2026-03-28 07:00:00    3626.292500           3307.82   318.47     318.47
# 2026-03-28 08:00:00    3672.085000           3323.67   348.41     348.41
# 2026-03-28 09:00:00    3817.231667           3450.75   366.48     366.48
# 2026-03-28 10:00:00    4035.650000           3604.73   430.92     430.92
# 2026-03-28 11:00:00    4105.934167           3709.30   396.64     396.64
# 2026-03-28 12:00:00    4109.691667           3804.52   305.17     305.17
# 2026-03-28 13:00:00    3865.866667           3665.06   200.81     200.81
# 2026-03-28 14:00:00    3899.966667           3604.39   295.58     295.58
# 2026-03-28 15:00:00    3935.327500           3588.99   346.34     346.34
# 2026-03-28 16:00:00    3985.295000           3556.47   428.82     428.82
# 2026-03-28 17:00:00    4041.984167           3663.83   378.16     378.16
# 2026-03-28 18:00:00    4113.289167           3699.19   414.10     414.10
# 2026-03-28 19:00:00    4116.083333           3705.56   410.52     410.52
# 2026-03-28 20:00:00    3934.310000           3594.94   339.37     339.37
# 2026-03-28 21:00:00    3738.565000           3426.71   311.86     311.86
# 2026-03-28 22:00:00    3596.029167           3290.24   305.78     305.78
# 2026-03-28 23:00:00    3460.873000           3255.20   205.67     205.67
# 2026-03-29 00:00:00    3259.830000           2930.56   329.27     329.27
# 2026-03-29 01:00:00    3110.151667           2735.53   374.62     374.62
# 2026-03-29 02:00:00    3008.414167           2608.51   399.90     399.90
# 2026-03-29 03:00:00    2946.469167           2577.94   368.53     368.53
# 2026-03-29 04:00:00    2925.082500           2593.23   331.86     331.86
# 2026-03-29 05:00:00    3040.604167           2670.07   370.53     370.53
# 2026-03-29 06:00:00    3268.691667           2837.78   430.92     430.92
# 2026-03-29 07:00:00    3453.409167           3097.46   355.95     355.95
# 2026-03-29 08:00:00    3509.320833           3102.10   407.22     407.22
# 2026-03-29 09:00:00    3661.414167           3184.58   476.84     476.84
# 2026-03-29 10:00:00    3904.752500           3295.11   609.64     609.64
# 2026-03-29 11:00:00    3984.550000           3407.60   576.95     576.95
# 2026-03-29 12:00:00    3980.638333           3379.36   601.28     601.28
# 2026-03-29 13:00:00    3848.738333           3336.80   511.94     511.94
# 2026-03-29 14:00:00    3893.573333           3377.31   516.27     516.27
# 2026-03-29 15:00:00    3882.495000           3419.55   462.94     462.94
# 2026-03-29 16:00:00    3896.236667           3193.47   702.77     702.77
# 2026-03-29 17:00:00    3972.124167           3331.82   640.31     640.31
# 2026-03-29 18:00:00    4067.191667           3430.16   637.03     637.03
# 2026-03-29 19:00:00    4086.340000           3484.14   602.20     602.20
# 2026-03-29 20:00:00    3965.816667           3301.40   664.42     664.42
# 2026-03-29 21:00:00    3808.692500           3195.42   613.28     613.28
# 2026-03-29 22:00:00    3691.999167           3203.06   488.93     488.93
# 2026-03-29 23:00:00    3564.636000           3159.12   405.51     405.51
# 2026-03-30 00:00:00    3344.881667           2937.81   407.08     407.08
# 2026-03-30 01:00:00    3168.007500           2729.67   438.34     438.34
# 2026-03-30 02:00:00    3044.461667           2669.11   375.35     375.35
# 2026-03-30 03:00:00    2977.455000           2613.43   364.02     364.02
# 2026-03-30 04:00:00    2972.238333           2672.14   300.10     300.10
# 2026-03-30 05:00:00    3128.199167           2761.24   366.96     366.96
# 2026-03-30 06:00:00    3492.726667           3061.74   430.98     430.98
# 2026-03-30 07:00:00    3775.683333           3407.01   368.67     368.67
# 2026-03-30 08:00:00    3869.929167           3490.34   379.59     379.59
# 2026-03-30 09:00:00    4143.052500           3687.16   455.89     455.89
# 2026-03-30 10:00:00    4401.778333           3863.49   538.28     538.28
# 2026-03-30 11:00:00    4446.052500           4043.69   402.36     402.36
# 2026-03-30 12:00:00    4500.645833           3947.30   553.34     553.34
# 2026-03-30 13:00:00    4355.289167           3594.12   761.17     761.17
# 2026-03-30 14:00:00    4373.597500           3543.81   829.79     829.79
# 2026-03-30 15:00:00    4365.740000           3598.64   767.10     767.10
# 2026-03-30 16:00:00    4338.495000           3520.21   818.29     818.29
# 2026-03-30 17:00:00    4255.975000           3565.26   690.72     690.72
# 2026-03-30 18:00:00    4264.064167           3656.63   607.44     607.44
# 2026-03-30 19:00:00    4298.858333           3632.96   665.90     665.90
# 2026-03-30 20:00:00    4065.030833           3484.69   580.34     580.34
# 2026-03-30 21:00:00    3852.061667           3312.19   539.87     539.87
# 2026-03-30 22:00:00    3733.551667           3205.48   528.07     528.07
# 2026-03-30 23:00:00    3559.261000           3132.78   426.48     426.48
# 2026-03-31 00:00:00    3341.876667           2828.13   513.75     513.75
# 2026-03-31 01:00:00    3171.556667           2700.73   470.83     470.83
# 2026-03-31 02:00:00    3052.315000           2610.94   441.37     441.37
# 2026-03-31 03:00:00    2987.943333           2542.77   445.18     445.18
# 2026-03-31 04:00:00    2964.380000           2654.96   309.42     309.42
# 2026-03-31 05:00:00    3092.273333           2813.39   278.88     278.88
# 2026-03-31 06:00:00    3391.844167           3132.63   259.22     259.22
# 2026-03-31 07:00:00    3671.264167           3455.92   215.35     215.35
# 2026-03-31 08:00:00    3745.175000           3542.27   202.90     202.90
# 2026-03-31 09:00:00    3999.338333           3737.35   261.99     261.99
# 2026-03-31 10:00:00    4291.773333           3918.46   373.31     373.31
# 2026-03-31 11:00:00    4322.950000           4066.33   256.62     256.62
# 2026-03-31 12:00:00    4366.121667           3963.23   402.89     402.89
# 2026-03-31 13:00:00    4175.753333           3625.60   550.16     550.16
# 2026-03-31 14:00:00    4333.295000           3663.44   669.86     669.86
# 2026-03-31 15:00:00    4318.812500           3620.89   697.92     697.92
# 2026-03-31 16:00:00    4223.345833           3533.03   690.31     690.31
# 2026-03-31 17:00:00    4202.099167           3626.25   575.85     575.85
# 2026-03-31 18:00:00    4219.912500           3704.85   515.07     515.07
# 2026-03-31 19:00:00    4138.271667           3580.94   557.33     557.33
# 2026-03-31 20:00:00    3850.250000           3305.97   544.28     544.28
# 2026-03-31 21:00:00    3569.006667           3143.87   425.13     425.13
# 2026-03-31 22:00:00    3411.328333           3017.76   393.57     393.57
# 2026-03-31 23:00:00    3266.566000           2972.81   293.76     293.76
# 2026-04-01 00:00:00    3048.977500           2990.39    58.58      58.58
# 2026-04-01 01:00:00    2890.407500           2843.61    46.80      46.80
# 2026-04-01 02:00:00    2808.920000           2615.54   193.38     193.38
# 2026-04-01 03:00:00    2745.719167           2514.00   231.72     231.72
# 2026-04-01 04:00:00    2749.545833           2580.65   168.90     168.90
# 2026-04-01 05:00:00    2990.898333           2825.83   165.07     165.07
# 2026-04-01 06:00:00    3526.418333           3153.86   372.55     372.55
# 2026-04-01 07:00:00    3727.845833           3314.05   413.79     413.79
# 2026-04-01 08:00:00    3763.586667           3380.21   383.37     383.37
# 2026-04-01 09:00:00    3958.506667           3638.33   320.17     320.17
# 2026-04-01 10:00:00    4215.413333           3944.22   271.19     271.19
# 2026-04-01 11:00:00    4289.895833           4127.94   161.95     161.95
# 2026-04-01 12:00:00    4266.035833           4138.55   127.49     127.49
# 2026-04-01 13:00:00    4086.259167           3927.59   158.67     158.67
# 2026-04-01 14:00:00    4187.285833           3939.19   248.10     248.10
# 2026-04-01 15:00:00    4181.297500           4049.70   131.60     131.60
# 2026-04-01 16:00:00    4186.305833           4058.15   128.16     128.16
# 2026-04-01 17:00:00    4202.999167           4096.83   106.17     106.17
# 2026-04-01 18:00:00    4241.965833           4061.55   180.42     180.42
# 2026-04-01 19:00:00    4280.077500           4050.56   229.52     229.52
# 2026-04-01 20:00:00    4054.515833           3798.52   255.99     255.99
# 2026-04-01 21:00:00    3820.569167           3665.84   154.73     154.73
# 2026-04-01 22:00:00    3686.049167           3670.67    15.38      15.38
# 2026-04-01 23:00:00    3606.980000           3768.09  -161.11     161.11

# %%
ens_only_sorted = ens_only.sort_values('Accuracy', ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Accuracy
colors = ['#27ae60' if a >= 90 else '#f39c12' if a >= 85 else '#e74c3c' for a in ens_only_sorted['Accuracy']]
bars = axes[0].barh(ens_only_sorted['region'], ens_only_sorted['Accuracy'], color=colors, alpha=0.85)
axes[0].axvline(90, color='red', linestyle='--', label='90% target')
axes[0].set_xlabel('Accuracy (100 - MAPE) %')
axes[0].set_title('Ensemble Model Accuracy per Region', fontweight='bold')
axes[0].legend()
for bar, v in zip(bars, ens_only_sorted['Accuracy']):
    axes[0].text(v+0.1, bar.get_y()+bar.get_height()/2, f'{v:.2f}%', va='center', fontsize=10)

# MAPE comparison: XGB vs LGB vs CAT vs Ensemble per region
x = np.arange(len(REGIONS))
w = 0.2
for i, model in enumerate(['XGB','LGB','CAT','ENSEMBLE']):
    vals = [metrics_df[metrics_df['region']==f'{r}_{model}']['MAPE'].values[0] for r in REGIONS]
    axes[1].bar(x + i*w, vals, width=w, label=model, alpha=0.85)
axes[1].set_xticks(x + 1.5*w); axes[1].set_xticklabels(REGIONS)
axes[1].set_ylabel('MAPE (%)')
axes[1].set_title('MAPE Comparison: Individual vs Ensemble', fontweight='bold')
axes[1].legend()
axes[1].axhline(10, color='red', linestyle='--', label='10% MAPE target')

plt.tight_layout()
plt.savefig('06_accuracy_comparison.png', bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# XGBoost feature importance for DELHI
xgb_imp = pd.Series(all_models['DELHI']['xgb'].feature_importances_, index=FEATURES).sort_values(ascending=True)
xgb_imp.tail(15).plot(kind='barh', ax=axes[0], color='#e74c3c', alpha=0.85)
axes[0].set_title('XGBoost Feature Importance — DELHI', fontweight='bold')
axes[0].set_xlabel('Importance Score')

# LightGBM feature importance for DELHI
lgb_imp = pd.Series(all_models['DELHI']['lgb'].feature_importances_, index=FEATURES).sort_values(ascending=True)
lgb_imp.tail(15).plot(kind='barh', ax=axes[1], color='#27ae60', alpha=0.85)
axes[1].set_title('LightGBM Feature Importance — DELHI', fontweight='bold')
axes[1].set_xlabel('Importance Score')

plt.tight_layout()
plt.savefig('08_feature_importance.png', bbox_inches='tight')
plt.show()

print('Top 5 features (XGBoost):', list(xgb_imp.tail(5).index[::-1]))
print('Top 5 features (LightGBM):', list(lgb_imp.tail(5).index[::-1]))
# Out:
# Top 5 features (XGBoost): ['feels_like', 'is_winter', 'month_cos', 'is_morning_peak', 'hour_cos']
# Top 5 features (LightGBM): ['day_of_year', 'Temperature (°C)', 'Relative Humidity (%)', 'feels_like', 'hour']

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for i, r in enumerate(REGIONS):
    actual   = test_df[r].values
    pred     = all_preds[r]
    residuals = actual - pred
    
    axes[i].scatter(pred, residuals, alpha=0.15, s=5, color='#3498db')
    axes[i].axhline(0, color='red', linewidth=1.5)
    axes[i].axhline(residuals.std(), color='orange', linestyle='--', linewidth=1, label=f'±1σ={residuals.std():.0f}MW')
    axes[i].axhline(-residuals.std(), color='orange', linestyle='--', linewidth=1)
    axes[i].set_xlabel('Predicted (MW)')
    axes[i].set_ylabel('Residual (MW)')
    axes[i].set_title(f'{r} — Residuals (σ={residuals.std():.1f}MW)', fontweight='bold')
    axes[i].legend(fontsize=8)

plt.suptitle('Residual Plots — Ensemble Model (Test 2026)', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('09_residuals.png', bbox_inches='tight')
plt.show()

print('Residual std by region (lower = less variance = better):')
for r in REGIONS:
    res = test_df[r].values - all_preds[r]
    print(f'  {r}: σ={res.std():.2f} MW, mean={res.mean():.2f} MW (bias)')
# Out:
# Residual std by region (lower = less variance = better):
#   DELHI: σ=357.86 MW, mean=110.59 MW (bias)
#   BRPL: σ=159.33 MW, mean=52.06 MW (bias)
#   BYPL: σ=93.56 MW, mean=17.90 MW (bias)
#   NDPL: σ=122.17 MW, mean=25.57 MW (bias)
#   NDMC: σ=20.68 MW, mean=17.45 MW (bias)
#   MES: σ=3.38 MW, mean=-0.40 MW (bias)

# %%
os.makedirs('models', exist_ok=True)

for region in REGIONS:
    # Save individual models
    joblib.dump(all_models[region]['xgb'], f'models/{region}_xgboost.pkl')
    joblib.dump(all_models[region]['lgb'], f'models/{region}_lightgbm.pkl')
    joblib.dump(all_models[region]['cat'], f'models/{region}_catboost.pkl')
    # Save ensemble weights
    joblib.dump(all_weights[region], f'models/{region}_weights.pkl')

# Save features list and metadata
metadata = {
    'features': FEATURES,
    'regions': REGIONS,
    'holiday_set': list(HOLIDAY_SET),
    'train_end': '2025-12-31',
    'test_start': '2026-01-01'
}
joblib.dump(metadata, 'models/metadata.pkl')

# List saved files
print('✅ Saved models:')
for f in sorted(os.listdir('models')):
    size = os.path.getsize(f'models/{f}') / 1024
    print(f'  models/{f} ({size:.1f} KB)')
# Out:
# ✅ Saved models:
#   models/.ipynb_checkpoints (0.0 KB)
#   models/BRPL_catboost.pkl (1043.6 KB)
#   models/BRPL_lightgbm.pkl (950.8 KB)
#   models/BRPL_weights.pkl (0.2 KB)
#   models/BRPL_xgboost.pkl (1088.4 KB)
#   models/BYPL_catboost.pkl (214.0 KB)
#   models/BYPL_lightgbm.pkl (664.0 KB)
#   models/BYPL_weights.pkl (0.2 KB)
#   models/BYPL_xgboost.pkl (953.6 KB)
#   models/DELHI_catboost.pkl (1179.5 KB)
#   models/DELHI_lightgbm.pkl (4513.2 KB)
#   models/DELHI_weights.pkl (0.2 KB)
#   models/DELHI_xgboost.pkl (2083.8 KB)
#   models/MES_catboost.pkl (1064.3 KB)
#   models/MES_lightgbm.pkl (3276.6 KB)
#   models/MES_weights.pkl (0.2 KB)
#   models/MES_xgboost.pkl (2327.7 KB)
#   models/NDMC_catboost.pkl (587.8 KB)
#   models/NDMC_lightgbm.pkl (1622.2 KB)
#   models/NDMC_weights.pkl (0.2 KB)
#   models/NDMC_xgboost.pkl (1679.2 KB)
#   models/NDPL_catboost.pkl (867.5 KB)
#   models/NDPL_lightgbm.pkl (1436.0 KB)
#   models/NDPL_weights.pkl (0.2 KB)
#   models/NDPL_xgboost.pkl (2245.9 KB)
#   models/ensemble_weights.pkl (0.5 KB)
#   models/metadata.pkl (1.6 KB)
